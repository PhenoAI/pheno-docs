# %% [raw]
# ---
# output-file: 012-carotid_ultrasound.html
# title: 012-carotid_ultrasound
# ---

# %% [markdown]
# # Carotid ultrasound dataset
#
# ### Description
#
# Carotid intima–media thickness computed from carotid ultrasound imaging.
#
# ### Introduction
#
# Carotid intima-media thickness (CIMT) measurement is an ultrasound-based technique used to assess the thickness of the innermost two layers of the carotid artery, known as the intima and media. These layers can become thickened due to atherosclerotic processes or due to age. The thickening of the intima-media layer can be throughout the length of the artery (increased IMT) or as local accumulation of fatty deposits that penetrate into the vessel interior known  as plaques. Advanced plaques can cause stenosis of the artery. Carotid IMT is increasingly used as an indicator of early atherosclerosis and a predictor for cardiovascular events and can be used for identifying asymptomatic patients at high risk who might be candidates for more intensive medical interventions. Measurement of CIMT with B-mode ultrasound is a noninvasive, sensitive, and reproducible technique for identifying and quantifying subclinical vascular disease and for evaluating CVD risk.
#
# The ultrasound probe is placed on the skin over the carotid artery and high-frequency sound waves are used to produce images of the artery. These images are then analyzed using an automatic detection algorithm to measure the thickness of the intima and media layers.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Carotid US was performed using the Supersonic Aixplorer MACH 30 (Hologic, USA). Carotid Intima Media (CIMT) was measured using the L10-2 transducer from both carotid arteries while the subject in supine position with head rotated to the opposite side of the measured artery. Evaluation was performed using an automatic computerized system (Aixplorer Mach 30). The intima and media are automatically traced within the box of interest. Mean CIMT was recorded over a length of 1 cm at the far wall of each carotid artery. One measurement was obtained from each carotid artery. Only parts of the carotid artery without plaques were included in the IMT analysis.
#
# ![IMT example](data:image/png;base64,...)
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `carotid_ultrasound.parquet`
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/012-carotid_ultrasound.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/12)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('carotid_ultrasound')
pl
# Out:
# PhenoLoader for carotid_ultrasound with
# 11 fields
# 2 tables: ['carotid_ultrasound', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                               field_string  \
# tabular_field_name
# timezone                                          Timezone
# collection_date               Collection date (YYYY-MM-DD)
# collection_timestamp                  Collection timestamp
# imt_left                     Intima media thickness (left)
# imt_right                   Intima media thickness (right)
# imt_window_width_left              IMT window width (left)
# imt_window_width_right            IMT window width (right)
# imt_fit_left             Intima media thickness Fit (left)
# imt_fit_right           Intima media thickness Fit (right)
#
#                                                        description_string  \
# tabular_field_name
# timezone                                           Timezone at collection
# collection_date                              Collection date (YYYY-MM-DD)
# collection_timestamp                                 Collection timestamp
# imt_left                Intima Media Thickness (IMT) measurement is an...
# imt_right               Intima Media Thickness (IMT) measurement is an...
# imt_window_width_left          Indicates the width if the box of interest
# imt_window_width_right         Indicates the width if the box of interest
# imt_fit_left            Percentage of the box of interest for which th...
# imt_fit_right           Percentage of the box of interest for which th...
#
#                         folder_id         feature_set            field_type  \
# tabular_field_name
# timezone                       12  carotid_ultrasound  Categorical (single)
# collection_date                12  carotid_ultrasound                  Date
# collection_timestamp           12  carotid_ultrasound              Datetime
# imt_left                       12  carotid_ultrasound            Continuous
# imt_right                      12  carotid_ultrasound            Continuous
# imt_window_width_left          12  carotid_ultrasound            Continuous
# imt_window_width_right         12  carotid_ultrasound            Continuous
# imt_fit_left                   12  carotid_ultrasound            Continuous
# imt_fit_right                  12  carotid_ultrasound            Continuous
#
#                                  strata data_coding   array  \
# tabular_field_name
# timezone                Collection time      001_03  Single
# collection_date         Collection time         NaN  Single
# collection_timestamp    Collection time         NaN  Single
# imt_left                        Primary         NaN  Single
# imt_right                       Primary         NaN  Single
# imt_window_width_left         Auxiliary         NaN  Single
# imt_window_width_right        Auxiliary         NaN  Single
# imt_fit_left                  Auxiliary         NaN  Single
# imt_fit_right                 Auxiliary         NaN  Single
#
#                                           pandas_dtype  bulk_file_extension  \
# tabular_field_name
# timezone                                      category                  NaN
# collection_date                         datetime64[ns]                  NaN
# collection_timestamp    datetime64[ns, Asia/Jerusalem]                  NaN
# imt_left                                         float                  NaN
# imt_right                                        float                  NaN
# imt_window_width_left                            float                  NaN
# imt_window_width_right                           float                  NaN
# imt_fit_left                                     float                  NaN
# imt_fit_right                                    float                  NaN
#
#                                                     relative_location units  \
# tabular_field_name
# timezone                carotid_ultrasound/carotid_ultrasound.parquet   NaN
# collection_date         carotid_ultrasound/carotid_ultrasound.parquet   NaN
# collection_timestamp    carotid_ultrasound/carotid_ultrasound.parquet   NaN
# imt_left                carotid_ultrasound/carotid_ultrasound.parquet    mm
# imt_right               carotid_ultrasound/carotid_ultrasound.parquet    mm
# imt_window_width_left   carotid_ultrasound/carotid_ultrasound.parquet    mm
# imt_window_width_right  carotid_ultrasound/carotid_ultrasound.parquet    mm
# imt_fit_left            carotid_ultrasound/carotid_ultrasound.parquet     %
# imt_fit_right           carotid_ultrasound/carotid_ultrasound.parquet     %
#
#                         bulk_dictionary  sampling_rate  transformation  \
# tabular_field_name
# timezone                            NaN            NaN             NaN
# collection_date                     NaN            NaN             NaN
# collection_timestamp                NaN            NaN             NaN
# imt_left                            NaN            NaN             NaN
# imt_right                           NaN            NaN             NaN
# imt_window_width_left               NaN            NaN             NaN
# imt_window_width_right              NaN            NaN             NaN
# imt_fit_left                        NaN            NaN             NaN
# imt_fit_right                       NaN            NaN             NaN
#
#                         list_of_tags stability       sexed       debut  \
# tabular_field_name
# timezone                         NaN  Accruing  Both sexes  2021-08-16
# collection_date                  NaN  Accruing  Both sexes  2021-08-16
# collection_timestamp             NaN  Accruing  Both sexes  2021-08-16
# imt_left                         NaN  Accruing  Both sexes  2021-08-16
# imt_right                        NaN  Accruing  Both sexes  2021-08-16
# imt_window_width_left            NaN  Accruing  Both sexes  2021-08-16
# imt_window_width_right           NaN  Accruing  Both sexes  2021-08-16
# imt_fit_left                     NaN  Accruing  Both sexes  2021-08-16
# imt_fit_right                    NaN  Accruing  Both sexes  2021-08-16
#
#                         completed
# tabular_field_name
# timezone                      NaN
# collection_date               NaN
# collection_timestamp          NaN
# imt_left                      NaN
# imt_right                     NaN
# imt_window_width_left         NaN
# imt_window_width_right        NaN
# imt_fit_left                  NaN
# imt_fit_right                 NaN

# %% [markdown]
# # Plot histogram and ecdf for imt_left at baseline visit

# %%
from pheno_utils.basic_plots import hist_ecdf_plots

col = "imt_left"
df = pl[[col] + ["age", "sex", "collection_date"]].loc[:,:,"00_00_visit",0,:]

# plot histogram and ecdf
hist_ecdf_plots(df.dropna(subset=[col,"sex", "age"]), col, gender_col="sex")

# stats
display(df[col].describe().to_frame().T)
# Out:
#            count     mean       std  min    25%    50%   75%   max
# imt_left  6291.0  0.60545  0.121213  0.4  0.517  0.586  0.67  1.29
