# %% [raw]
# ---
# output-file: 100-curated_phenotypes.html
# title: 100-curated_phenotypes
# ---

# %% [markdown]
# # Curated Phenotypes dataset
#
# ### Description
#
# Coming soon
#
# ### Introduction
#
# * Abdominal Adiposity: Increased abdominal obesity is a hallmark of fat or adiposity-related metabolic dysfunction.
# * ADHD: Attention deficit hyperactivity disorder (ADHD), one of the most common neuropsychiatric disorders of childhood and adolescence, often persists into adulthood.
# * Anxiety: People with anxiety disorders frequently have intense, excessive and persistent worry and fear about everyday situations.
# * BMI and Obesity: Overweight and obesity are associated with morbidity and mortality can lead to significant social and psychological challenges for individuals, including stigma, discrimination, and increased risk of mental health issues such as depression and low self-esteem.
# * CKD: Chronic Kidney Disease includes a range of pathophysiologic processes associated with abnormal kidney function and a progressive decline in glomerular filtration rate (GFR).
# * Depression: Depression is a constellation of symptoms and signs that may include depressed mood.
# * Diabetes: Type 2 Diabetes (T2D) is a health condition characterized by blood sugar levels that are higher than normal, whereas in prediabetes blood sugar levels are not high enough yet to be classified as T2D.
# * Endometriosis:  Endometriosis is a gynecological disease defined as endometrial glands and stroma that occur outside the uterine cavity.
# * Hyperlipidemia: Lipoproteins are complexes of lipids and proteins that are essential for transport of cholesterol, triglycerides (TGs), and fat-soluble vitamins in the blood. Disorders of lipoprotein metabolism include primary and secondary conditions that substantially increase or decrease specific circulating lipids (e.g., cholesterol or TGs) or lipoproteins (e.g., low density or high density lipoproteins).
# * Hypertension: Hypertension is the most common reason for office visits and for the use of chronic prescription medications. Roughly one-half of hypertensive individuals do not have adequate blood pressure control.
# * Ischemic Heart Disease: Ischemic heart disease (IHD), also referred to as coronary heart disease (CHD), is the term associated with an inadequate supply of blood to the myocardium due to obstruction of the epicardial coronary arteries, usually from atherosclerosis.
# * MAFLD: Metabolic (dysfunction) Associated Fatty Liver Disease / Non-alcoholic Fatty Liver Disease (NAFLD) was described as an excessive fat infiltration of the liver in the absence of significant alcohol consumption or other causes of liver disease.
# * Menopause: Natural menopause is defined as the permanent cessation of menstrual periods, determined retrospectively after a woman has experienced 12 months of amenorrhea without any other obvious pathologic or physiologic cause.
# * Migraine: Migraine is an episodic disorder that manifests in a severe headache generally associated with nausea and/or light and sound sensitivity.
# * NMSC: Nonmelanoma Skin Cancers are a group of cancers that arise from the skin but do not include melanoma. The most common types of nonmelanoma skin cancer are basal cell carcinoma (BCC) and squamous cell carcinoma (SCC).
# * OSA: Obstructive Sleep Apnea is a disorder that is characterized by obstructive apneas, hypopneas, and/or respiratory effort-related arousals caused by repetitive collapse of the upper airway during sleep.
# * Osteoporosis: Osteoporosis is characterized by low bone mass, microarchitectural disruption, and skeletal fragility, resulting in decreased bone strength and an increased risk of fracture.
# * Sarcopenia: Sarcopenia is a syndrome characterized by the loss of muscle mass, strength, and performance.
# * Sleep Quality: Sleep is considered a restorative process that allows for energy renewal and also for cellular. Low sleep quality may lead to accelerated aging by triggering DNA damage and chronic inflammation to influence the compensatory/resiliency systems of the human body.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Coming soon
#
# ### Data availability
# <!-- for the example notebooks -->
# Coming soon
#
# ### Relevant links
#
# Coming soon

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('curated_phenotypes')
pl
# Out:
# /home/ec2-user/projects/pheno-utils/pheno_utils/pheno_loader.py:641: UserWarning: No date field found
#   warnings.warn(f'No date field found')
# PhenoLoader for curated_phenotypes with
# 160 fields
# 19 tables: ['menopause', 'osteoporosis', 'migraine', 'depression', 'adhd', 'anxiety', 'abdominal_adiposity', 'bmi', 'osa', 'ckd', 'mafld', 'diabetes', 'ischemic_heart_disease', 'sleep_quality', 'hypertension', 'hyperlipidemia', 'nmsc', 'endometriosis', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                                                          field_string  \
# tabular_field_name
# menopause__curated_phenotype                                             menopause__curated_phenotype
# menopause__is_getting_period_ques                                   menopause__is_getting_period_ques
# menopause__menopause_age                                                     menopause__menopause_age
# menopause__female_current_menstural_cycle                   menopause__female_current_menstural_cycle
# menopause__extra_health_females_current_mestura...  menopause__extra_health_females_current_mestur...
# menopause__female_last_mestural_cycle_age                   menopause__female_last_mestural_cycle_age
# menopause__extra_health_females_last_mestural_c...  menopause__extra_health_females_last_mestural_...
# osteoporosis__curated_phenotype                                       osteoporosis__curated_phenotype
# osteoporosis__self_reported_osteoporosis                     osteoporosis__self_reported_osteoporosis
# osteoporosis__self_reported_osteopenia                         osteoporosis__self_reported_osteopenia
# osteoporosis__femurs_tscore_osteoporosis                     osteoporosis__femurs_tscore_osteoporosis
# osteoporosis__femurs_tscore_osteopenia                         osteoporosis__femurs_tscore_osteopenia
# osteoporosis__spine_tscore_osteoporosis                       osteoporosis__spine_tscore_osteoporosis
# osteoporosis__spine_tscore_osteopenia                           osteoporosis__spine_tscore_osteopenia
# osteoporosis__femurs_zscore_osteoporosis                     osteoporosis__femurs_zscore_osteoporosis
# osteoporosis__count_fractures                                           osteoporosis__count_fractures
# osteoporosis__menopause                                                       osteoporosis__menopause
# osteoporosis__sex                                                                   osteoporosis__sex
# osteoporosis__age_at_research_stage                               osteoporosis__age_at_research_stage
# osteoporosis__M05BA                                                               osteoporosis__M05BA
# osteoporosis__femur_bmd_min                                               osteoporosis__femur_bmd_min
# osteoporosis__femur_neck_bmd_min                                     osteoporosis__femur_neck_bmd_min
# osteoporosis__spine_l1_l4_bmd                                           osteoporosis__spine_l1_l4_bmd
# migraine__curated_phenotype                                               migraine__curated_phenotype
# migraine__severe_migraine_medication                             migraine__severe_migraine_medication
# migraine__other_migraine_medication                               migraine__other_migraine_medication
# migraine__self_reported_migraine                                     migraine__self_reported_migraine
# depression__curated_phenotype                                           depression__curated_phenotype
# depression__probable_recurrent_major_depression       depression__probable_recurrent_major_depression
# depression__self_reported_depression                             depression__self_reported_depression
# depression__ibs_depression_treatment_past                   depression__ibs_depression_treatment_past
# depression__taking_anti_depressants                               depression__taking_anti_depressants
# adhd__curated_phenotype                                                       adhd__curated_phenotype
# adhd__self_reported_ADHD                                                     adhd__self_reported_ADHD
# adhd__main_ADHD_medication                                                 adhd__main_ADHD_medication
# adhd__any_ADHD_medication                                                   adhd__any_ADHD_medication
# adhd__neuroticism_value                                                       adhd__neuroticism_value
# anxiety__self_reported_anxiety                                         anxiety__self_reported_anxiety
# anxiety__curated_phenotype                                                 anxiety__curated_phenotype
# anxiety__health_mental_current_worrier                         anxiety__health_mental_current_worrier
# abdominal_adiposity__curated_phenotype                         abdominal_adiposity__curated_phenotype
# abdominal_adiposity__total_scan_vat_mass                     abdominal_adiposity__total_scan_vat_mass
# abdominal_adiposity__total_scan_sat_mass                     abdominal_adiposity__total_scan_sat_mass
# abdominal_adiposity__vat_sat_ratio                                 abdominal_adiposity__vat_sat_ratio
# abdominal_adiposity__vat_index                                         abdominal_adiposity__vat_index
# abdominal_adiposity__waist_circumference                     abdominal_adiposity__waist_circumference
# abdominal_adiposity__waist_to_hip_ratio                          abdominal_adiposity__waist_hip_ratio
# abdominal_adiposity__visceral_adipose_index               abdominal_adiposity__visceral_adipose_index
# bmi__curated_phenotype                                                         bmi__curated_phenotype
# bmi__bmi                                                                                     bmi__bmi
# bmi__obesity_class                                                                 bmi__obesity_class
# bmi__had_bariatric_surgery                                                 bmi__had_bariatric_surgery
# bmi__self_reported_overweight                                           bmi__self_reported_overweight
# bmi__self_reported_obese                                                     bmi__self_reported_obese
# bmi__height                                                                               bmi__height
# bmi__weight                                                                               bmi__weight
# osa__curated_phenotype                                                         osa__curated_phenotype
# osa__self_reported_osa                                                         osa__self_reported_osa
# osa__ahi_max                                                                             osa__ahi_max
# osa__odi_max                                                                             osa__odi_max
# osa__rdi_max                                                                             osa__rdi_max
# ckd__egfr                                                                                    ckd__gfr
# ckd__curated_phenotype                                                         ckd__curated_phenotype
# ckd__blood_bun                                                                         ckd__blood_bun
# ckd__acr_categories                                                               ckd__acr_categories
# ckd__gfr_categories                                                               ckd__gfr_categories
# ckd__blood_creatinine                                                           ckd__blood_creatinine
# ckd__urine_acr                                                                         ckd__urine_acr
# ckd__urine_microalbumin                                                       ckd__urine_microalbumin
# ckd__urine_creatinine                                                           ckd__urine_creatinine
# ckd__self_reported_ckd                                                         ckd__self_reported_ckd
# mafld__self_reporting                                                           mafld__self_reporting
# mafld__speed_of_sound                                                           mafld__speed_of_sound
# mafld__curated_phenotype                                                     mafld__curated_phenotype
# mafld__bloodtest_alt                                                             mafld__bloodtest_alt
# mafld__bloodtest_alt_category                                           mafld__bloodtest_alt_category
# mafld__bloodtest_ast                                                             mafld__bloodtest_ast
# mafld__bloodtest_ast_category                                           mafld__bloodtest_ast_category
# mafld__de_ritis_ratio                                                           mafld__de_ritus_ratio
# mafld__de_ritis_ratio_category                                         mafld__de_ritus_ratio_category
# mafld__fibrosis_4                                                                   mafld__fibrosis_4
# mafld__fibrosis_4_category                                                 mafld__fibrosis_4_category
# diabetes__self_reported_diabetic                                     diabetes__self_reported_diabetes
# diabetes__self_reported_prediabetic                               diabetes__self_reported_prediabetes
# diabetes__curated_phenotype                                               diabetes__curated_phenotype
# diabetes__bloodtest_hba1c                                                   diabetes__bloodtest_hba1c
# diabetes__bloodtest_fpg                                                       diabetes__bloodtest_fpg
# diabetes__cgm_ea1c                                                                 diabetes__cgm_ea1c
# diabetes__cgm_hbgi                                                                 diabetes__cgm_hbgi
# diabetes__cgm_mage                                                                 diabetes__cgm_mage
# ischemic_heart_disease__curated_phenotype                   ischemic_heart_disease__curated_phenotype
# ischemic_heart_disease__self_reported_ischemic_...  ischemic_heart_disease__self_reported_ischemic...
# ischemic_heart_disease__nitrates                                     ischemic_heart_disease__nitrates
# ischemic_heart_disease__st_mv_aVF                                   ischemic_heart_disease__st_mv_aVF
# ischemic_heart_disease__st_mv_aVL                                   ischemic_heart_disease__st_mv_aVL
# ischemic_heart_disease__st_mv_aVR                                   ischemic_heart_disease__st_mv_aVR
# ischemic_heart_disease__st_mv_I                                       ischemic_heart_disease__st_mv_I
# ischemic_heart_disease__st_mv_II                                     ischemic_heart_disease__st_mv_II
# ischemic_heart_disease__st_mv_III                                   ischemic_heart_disease__st_mv_III
# ischemic_heart_disease__st_mv_V1                                     ischemic_heart_disease__st_mv_V1
# ischemic_heart_disease__st_mv_V2                                     ischemic_heart_disease__st_mv_V2
# ischemic_heart_disease__st_mv_V3                                     ischemic_heart_disease__st_mv_V3
# ischemic_heart_disease__st_mv_V4                                     ischemic_heart_disease__st_mv_V4
# ischemic_heart_disease__st_mv_V5                                     ischemic_heart_disease__st_mv_V5
# ischemic_heart_disease__st_mv_V6                                     ischemic_heart_disease__st_mv_V6
# sleep_quality__curated_phenotype                                     sleep_quality__curated_phenotype
# sleep_quality__sleep_index                                                 sleep_quality__sleep_index
# sleep_quality__sleep_index_lowrisk_snoring                 sleep_quality__sleep_index_lowrisk_snoring
# sleep_quality__sleep_index_lowrisk_chronotype           sleep_quality__sleep_index_lowrisk_chronotype
# sleep_quality__sleep_index_lowrisk_daytime                 sleep_quality__sleep_index_lowrisk_daytime
# sleep_quality__sleep_index_lowrisk_hours_daily         sleep_quality__sleep_index_lowrisk_hours_daily
# sleep_quality__sleep_index_lowrisk_insomnia               sleep_quality__sleep_index_lowrisk_insomnia
# sleep_quality__sleep_index_lowrisk_waking_morni...  sleep_quality__sleep_index_lowrisk_waking_morn...
# sleep_quality__number_of_wakes                                         sleep_quality__number_of_wakes
# sleep_quality__percent_of_deep_sleep_time                   sleep_quality__percent_of_deep_sleep_time
# sleep_quality__sleep_latency                                             sleep_quality__sleep_latency
# sleep_quality__total_sleep_time                                       sleep_quality__total_sleep_time
# sleep_quality__total_wake_time_after_sleep_onset     sleep_quality__total_wake_time_after_sleep_onset
# sleep_quality__sleep_efficiency                                       sleep_quality__sleep_efficiency
# hypertension__curated_phenotype                                       hypertension__curated_phenotype
# hypertension__self_reported_hypertension                     hypertension__self_reported_hypertension
# hypertension__sitting_blood_pressure_systolic           hypertension__sitting_blood_pressure_systolic
# hypertension__sitting_blood_pressure_diastolic         hypertension__sitting_blood_pressure_diastolic
# hypertension__lying_blood_pressure_systolic               hypertension__lying_blood_pressure_systolic
# hypertension__lying_blood_pressure_diastolic             hypertension__lying_blood_pressure_diastolic
# hypertension__l_brachial_pressure                                   hypertension__l_brachial_pressure
# hypertension__r_brachial_pressure                                   hypertension__r_brachial_pressure
# hypertension__acc_aha_ranges                                             hypertension__acc_aha_ranges
# hyperlipidemia__curated_phenotype                                   hyperlipidemia__curated_phenotype
# hyperlipidemia__hypertriglyceridemia                             hyperlipidemia__hypertriglyceridemia
# hyperlipidemia__hyperlipoproteinemia                             hyperlipidemia__hyperlipoproteinemia
# hyperlipidemia__combined_hyperlipoproteinemia           hyperlipidemia__combined_hyperlipoproteinemia
# hyperlipidemia__self_reported_hypertriglyceridemia  hyperlipidemia__self_reported_hypertriglycerid...
# hyperlipidemia__self_reported_hyperlipoproteinemia  hyperlipidemia__self_reported_hyperlipoprotein...
# hyperlipidemia__ldl_value                                                   hyperlipidemia__ldl_value
# hyperlipidemia__ldl_category                                             hyperlipidemia__ldl_category
# hyperlipidemia__nightingale_ldl_value                           hyperlipidemia__nightingale_ldl_value
# hyperlipidemia__total_cholesterol_value                       hyperlipidemia__total_cholesterol_value
# hyperlipidemia__total_cholesterol_category                 hyperlipidemia__total_cholesterol_category
# hyperlipidemia__triglycerides_value                               hyperlipidemia__triglycerides_value
# hyperlipidemia__triglycerides_category                         hyperlipidemia__triglycerides_category
# hyperlipidemia__nightingale_triglycerides_value       hyperlipidemia__nightingale_triglycerides_value
# hyperlipidemia__cholesterol_tg_ratio_value                 hyperlipidemia__cholesterol_tg_ratio_value
# hyperlipidemia__cholesterol_tg_ratio_category           hyperlipidemia__cholesterol_tg_ratio_category
# hyperlipidemia__hdl_value                                                   hyperlipidemia__hdl_value
# hyperlipidemia__hdl_category                                             hyperlipidemia__hdl_category
# hyperlipidemia__nightingale_hdl_value                           hyperlipidemia__nightingale_hdl_value
# nmsc__curated_phenotype                                                       nmsc__curated_phenotype
# nmsc__self_reported_nmsc                                                     nmsc__self_reported_nmsc
# nmsc__self_reported_bcc                                                       nmsc__self_reported_bcc
# nmsc__self_reported_scc                                                       nmsc__self_reported_scc
# nmsc__self_reported_and_treated_bcc                               nmsc__self_reported_and_treated_bcc
# nmsc__self_reported_and_treated_scc                               nmsc__self_reported_and_treated_scc
# nmsc__mole_biopsy                                                                   nmsc__mole_biopsy
# endometriosis__curated_phenotype                                     endometriosis__curated_phenotype
# endometriosis__self_reported_endometriosis                 endometriosis__self_reported_endometriosis
# endometriosis__self_reported_and_surgery                     endometriosis__self_reported_and_surgery
# endometriosis__self_reported_and_premenopausal         endometriosis__self_reported_and_premenopausal
#
#                                                                                    description_string  \
# tabular_field_name
# menopause__curated_phenotype                                                 Curated menopause status
# menopause__is_getting_period_ques                           Is the participant still getting periods?
# menopause__menopause_age                                                             Age at menopause
# menopause__female_current_menstural_cycle                                     Current menstrual cycle
# menopause__extra_health_females_current_mestura...  Extra health information about current menstru...
# menopause__female_last_mestural_cycle_age                                 Age at last menstrual cycle
# menopause__extra_health_females_last_mestural_c...  Extra health information about last menstrual ...
# osteoporosis__curated_phenotype                              Curated Osteoporosis/Osteopenia category
# osteoporosis__self_reported_osteoporosis                                   Self reported osteoporosis
# osteoporosis__self_reported_osteopenia                                       Self reported osteopenia
# osteoporosis__femurs_tscore_osteoporosis                        Femurs T-score Osteoporosis (<= -2.5)
# osteoporosis__femurs_tscore_osteopenia                         Femurs T-score Osteopenia (-2.5 to -1)
# osteoporosis__spine_tscore_osteoporosis                          Spine T-score Osteoporosis (<= -2.5)
# osteoporosis__spine_tscore_osteopenia                           Spine T-score Osteopenia (-2.5 to -1)
# osteoporosis__femurs_zscore_osteoporosis                          Femurs Z-score Osteoporosis (<= -2)
# osteoporosis__count_fractures                                               Count of fractures events
# osteoporosis__menopause                                                              Menopause status
# osteoporosis__sex                                                                     Is male boolean
# osteoporosis__age_at_research_stage                                             Age at research stage
# osteoporosis__M05BA                                     ICD11 code M05BA medication - Bisphosphonates
# osteoporosis__femur_bmd_min                                              Femur BMD left/right minimum
# osteoporosis__femur_neck_bmd_min                                    Femur neck BMD left/right minimum
# osteoporosis__spine_l1_l4_bmd                                                         Spine L1-L4 BMD
# migraine__curated_phenotype                                                 Curated migraine category
# migraine__severe_migraine_medication                                       Severe migraine medication
# migraine__other_migraine_medication                                         Other migraine medication
# migraine__self_reported_migraine                                               Self-reported migraine
# depression__curated_phenotype                                             Curated depression category
# depression__probable_recurrent_major_depression     Probable recurrent major depression. Based on ...
# depression__self_reported_depression                                         Self-reported depression
# depression__ibs_depression_treatment_past           Irritable Bowel Syndrome (IBS) questionnaire h...
# depression__taking_anti_depressants                                           Taking anti-depressants
# adhd__curated_phenotype                                                         Curated ADHD category
# adhd__self_reported_ADHD                                                           Self-reported ADHD
# adhd__main_ADHD_medication                                                       Main ADHD medication
# adhd__any_ADHD_medication                                                         Any ADHD medication
# adhd__neuroticism_value                                                             Neuroticism value
# anxiety__self_reported_anxiety                                                  Self-reported anxiety
# anxiety__curated_phenotype                                                   Curated anxiety category
# anxiety__health_mental_current_worrier                                                Current worrier
# abdominal_adiposity__curated_phenotype              Abdominal Obesity (healthy, increased risk, high)
# abdominal_adiposity__total_scan_vat_mass                Total Scan Visceral Adipose Tissue (VAT) Mass
# abdominal_adiposity__total_scan_sat_mass            Total Scan Subcutaneous Adipose Tissue (SAT) Mass
# abdominal_adiposity__vat_sat_ratio                                                      VAT/SAT Ratio
# abdominal_adiposity__vat_index                                                       VAT Index (VATI)
# abdominal_adiposity__waist_circumference                                          Waist Circumference
# abdominal_adiposity__waist_to_hip_ratio                                               Waist/Hip Ratio
# abdominal_adiposity__visceral_adipose_index                              Visceral Adipose Index (VAI)
# bmi__curated_phenotype                                                           Curated BMI category
# bmi__bmi                                                                                          BMI
# bmi__obesity_class                                                                      Obesity class
# bmi__had_bariatric_surgery                                                      Had bariatric surgery
# bmi__self_reported_overweight                                                Self-reported overweight
# bmi__self_reported_obese                                                          Self-reported obese
# bmi__height                                                                                    Height
# bmi__weight                                                                                    Weight
# osa__curated_phenotype                                                          Curated OSA phenotype
# osa__self_reported_osa                                          Self-reported obstructive sleep apnea
# osa__ahi_max                                                     max Apnea-hypopnea index over nights
# osa__odi_max                                                max Oxygen desaturation index over nights
# osa__rdi_max                                            max Respiratory disturbance index over nights
# ckd__egfr                                                       Glomerular filtration rate (GFR) test
# ckd__curated_phenotype                              Kidney Disease: Improving Global Outcomes (KDI...
# ckd__blood_bun                                                         Blood urea nitrogen (BUN) test
# ckd__acr_categories                                      Albumin-to-creatinine ratio (ACR) categories
# ckd__gfr_categories                                       Glomerular filtration rate (GFR) categories
# ckd__blood_creatinine                                                     Serum creatinine blood test
# ckd__urine_acr                                                Urine albumin-to-creatinine ratio (ACR)
# ckd__urine_microalbumin                                                       Urine microalbumin test
# ckd__urine_creatinine                                                           Urine creatinine test
# ckd__self_reported_ckd                                           Self-reported chronic kidney disease
# mafld__self_reporting                                                         Self-reporting of NAFLD
# mafld__speed_of_sound                                   Median valud of 3 Speed of sound measurements
# mafld__curated_phenotype                                                      Curated NAFLD phenotype
# mafld__bloodtest_alt                                        Alanine aminotransferase (ALT) blood test
# mafld__bloodtest_alt_category                       Categorical strata of Alanine aminotransferase...
# mafld__bloodtest_ast                                      Aspartate aminotransferase (AST) blood test
# mafld__bloodtest_ast_category                       Categorical strata of Aspartate aminotransfera...
# mafld__de_ritis_ratio                                                        De Ritis ratio (AST/ALT)
# mafld__de_ritis_ratio_category                         Categorical strata of De Ritis ratio (AST/ALT)
# mafld__fibrosis_4                                                            Fibrosis-4 (FIB-4) score
# mafld__fibrosis_4_category                             Categorical strata of Fibrosis-4 (FIB-4) score
# diabetes__self_reported_diabetic                                               Self-reported diabetes
# diabetes__self_reported_prediabetic                                         Self-reported prediabetes
# diabetes__curated_phenotype                                                 Curated diabetes category
# diabetes__bloodtest_hba1c                                                            HbA1c blood test
# diabetes__bloodtest_fpg                                       Fasting plasma glucose (FPG) blood test
# diabetes__cgm_ea1c                                  Estimated HbA1c from continuous glucose monito...
# diabetes__cgm_hbgi                                  Hypoglycemia Index (HBGI) from continuous gluc...
# diabetes__cgm_mage                                  Mean Amplitude of Glycemic Excursions (MAGE) f...
# ischemic_heart_disease__curated_phenotype                     Curated ischemic heart disease category
# ischemic_heart_disease__self_reported_ischemic_...               Self-reported ischemic heart disease
# ischemic_heart_disease__nitrates                                                      Taking nitrates
# ischemic_heart_disease__st_mv_aVF                                         ST segment elevation in aVF
# ischemic_heart_disease__st_mv_aVL                                         ST segment elevation in aVL
# ischemic_heart_disease__st_mv_aVR                                         ST segment elevation in aVR
# ischemic_heart_disease__st_mv_I                                             ST segment elevation in I
# ischemic_heart_disease__st_mv_II                                           ST segment elevation in II
# ischemic_heart_disease__st_mv_III                                         ST segment elevation in III
# ischemic_heart_disease__st_mv_V1                                           ST segment elevation in V1
# ischemic_heart_disease__st_mv_V2                                           ST segment elevation in V2
# ischemic_heart_disease__st_mv_V3                                           ST segment elevation in V3
# ischemic_heart_disease__st_mv_V4                                           ST segment elevation in V4
# ischemic_heart_disease__st_mv_V5                                           ST segment elevation in V5
# ischemic_heart_disease__st_mv_V6                                           ST segment elevation in V6
# sleep_quality__curated_phenotype                                      Curated sleep quality phenotype
# sleep_quality__sleep_index                          Sleep Index (Gao et al.), (0 [worst]–6 [best])...
# sleep_quality__sleep_index_lowrisk_snoring          Sleep Index component: snoring is at low risk ...
# sleep_quality__sleep_index_lowrisk_chronotype       Sleep Index component: chronotype is at low ri...
# sleep_quality__sleep_index_lowrisk_daytime          Sleep Index component: daytime sleepiness is a...
# sleep_quality__sleep_index_lowrisk_hours_daily      Sleep Index component: hours of sleep per day ...
# sleep_quality__sleep_index_lowrisk_insomnia         Sleep Index component: insomnia is at low risk...
# sleep_quality__sleep_index_lowrisk_waking_morni...  Sleep Index component: waking up in the mornin...
# sleep_quality__number_of_wakes                                       Number of wakes during the night
# sleep_quality__percent_of_deep_sleep_time                               Percentage of deep sleep time
# sleep_quality__sleep_latency                                            Time until first sleep period
# sleep_quality__total_sleep_time                                         The total sleep time at night
# sleep_quality__total_wake_time_after_sleep_onset             Total wake time after sleep onset (WASO)
# sleep_quality__sleep_efficiency                               Percentage of sleep time from the night
# hypertension__curated_phenotype                                         Curated hypertension category
# hypertension__self_reported_hypertension                                   Self reported hypertension
# hypertension__sitting_blood_pressure_systolic                         Sitting blood pressure systolic
# hypertension__sitting_blood_pressure_diastolic                       Sitting blood pressure diastolic
# hypertension__lying_blood_pressure_systolic                             Lying blood pressure systolic
# hypertension__lying_blood_pressure_diastolic                           Lying blood pressure diastolic
# hypertension__l_brachial_pressure                                              Left brachial pressure
# hypertension__r_brachial_pressure                                             Right brachial pressure
# hypertension__acc_aha_ranges                        ACC/AHA Ranges of Hypertension based on solely...
# hyperlipidemia__curated_phenotype                      see hyperlipoproteinemia, hypertriglyceridemia
# hyperlipidemia__hypertriglyceridemia                           Hypertriglyceridemia curated phenotype
# hyperlipidemia__hyperlipoproteinemia                           Hyperlipoproteinemia curated phenotype
# hyperlipidemia__combined_hyperlipoproteinemia                   Combined (Mixed) Hyperlipoproteinemia
# hyperlipidemia__self_reported_hypertriglyceridemia                 Self-reported hypertriglyceridemia
# hyperlipidemia__self_reported_hyperlipoproteinemia                 Self-reported hyperlipoproteinemia
# hyperlipidemia__ldl_value                                                             LDL cholesterol
# hyperlipidemia__ldl_category                                                 LDL cholesterol category
# hyperlipidemia__nightingale_ldl_value                                     Nightingale LDL cholesterol
# hyperlipidemia__total_cholesterol_value                                             Total cholesterol
# hyperlipidemia__total_cholesterol_category                                 Total cholesterol category
# hyperlipidemia__triglycerides_value                                                     Triglycerides
# hyperlipidemia__triglycerides_category                                         Triglycerides category
# hyperlipidemia__nightingale_triglycerides_value                             Nightingale triglycerides
# hyperlipidemia__cholesterol_tg_ratio_value                                       Cholesterol TG ratio
# hyperlipidemia__cholesterol_tg_ratio_category                           Cholesterol TG ratio category
# hyperlipidemia__hdl_value                                                             HDL cholesterol
# hyperlipidemia__hdl_category                                                 HDL cholesterol category
# hyperlipidemia__nightingale_hdl_value                                     Nightingale HDL cholesterol
# nmsc__curated_phenotype                             Curated Non-Melanoma Skin Cancers (NMSCs) phen...
# nmsc__self_reported_nmsc                              Self-reported Non-Melanoma Skin Cancers (NMSCs)
# nmsc__self_reported_bcc                                      Self-reported Basal Cell Carcinoma (BCC)
# nmsc__self_reported_scc                                   Self-reported Squamous Cell Carcinoma (SCC)
# nmsc__self_reported_and_treated_bcc                 Self-reported and treated Basal Cell Carcinoma...
# nmsc__self_reported_and_treated_scc                 Self-reported and treated Squamous Cell Carcin...
# nmsc__mole_biopsy                                                                         Mole biopsy
# endometriosis__curated_phenotype                                           See self_reported* columns
# endometriosis__self_reported_endometriosis                                Self-reported endometriosis
# endometriosis__self_reported_and_surgery                      Self-reported endometriosis and surgery
# endometriosis__self_reported_and_premenopausal          Self-reported endometriosis and premenopausal
#
#                                                    customer_field  folder_id  \
# tabular_field_name
# menopause__curated_phenotype                                ready        NaN
# menopause__is_getting_period_ques                           ready        NaN
# menopause__menopause_age                                    ready        NaN
# menopause__female_current_menstural_cycle                   ready        NaN
# menopause__extra_health_females_current_mestura...          ready        NaN
# menopause__female_last_mestural_cycle_age                   ready        NaN
# menopause__extra_health_females_last_mestural_c...          ready        NaN
# osteoporosis__curated_phenotype                             ready        NaN
# osteoporosis__self_reported_osteoporosis                    ready        NaN
# osteoporosis__self_reported_osteopenia                      ready        NaN
# osteoporosis__femurs_tscore_osteoporosis                    ready        NaN
# osteoporosis__femurs_tscore_osteopenia                      ready        NaN
# osteoporosis__spine_tscore_osteoporosis                     ready        NaN
# osteoporosis__spine_tscore_osteopenia                       ready        NaN
# osteoporosis__femurs_zscore_osteoporosis                    ready        NaN
# osteoporosis__count_fractures                               ready        NaN
# osteoporosis__menopause                                     ready        NaN
# osteoporosis__sex                                           ready        NaN
# osteoporosis__age_at_research_stage                         ready        NaN
# osteoporosis__M05BA                                         ready        NaN
# osteoporosis__femur_bmd_min                                 ready        NaN
# osteoporosis__femur_neck_bmd_min                            ready        NaN
# osteoporosis__spine_l1_l4_bmd                               ready        NaN
# migraine__curated_phenotype                                 ready        NaN
# migraine__severe_migraine_medication                        ready        NaN
# migraine__other_migraine_medication                         ready        NaN
# migraine__self_reported_migraine                            ready        NaN
# depression__curated_phenotype                               ready        NaN
# depression__probable_recurrent_major_depression             ready        NaN
# depression__self_reported_depression                        ready        NaN
# depression__ibs_depression_treatment_past                   ready        NaN
# depression__taking_anti_depressants                         ready        NaN
# adhd__curated_phenotype                                     ready        NaN
# adhd__self_reported_ADHD                                    ready        NaN
# adhd__main_ADHD_medication                                  ready        NaN
# adhd__any_ADHD_medication                                   ready        NaN
# adhd__neuroticism_value                                     ready        NaN
# anxiety__self_reported_anxiety                              ready        NaN
# anxiety__curated_phenotype                                  ready        NaN
# anxiety__health_mental_current_worrier                      ready        NaN
# abdominal_adiposity__curated_phenotype                      ready        NaN
# abdominal_adiposity__total_scan_vat_mass                    ready        NaN
# abdominal_adiposity__total_scan_sat_mass                    ready        NaN
# abdominal_adiposity__vat_sat_ratio                          ready        NaN
# abdominal_adiposity__vat_index                              ready        NaN
# abdominal_adiposity__waist_circumference                    ready        NaN
# abdominal_adiposity__waist_to_hip_ratio                     ready        NaN
# abdominal_adiposity__visceral_adipose_index                 ready        NaN
# bmi__curated_phenotype                                      ready        NaN
# bmi__bmi                                                    ready        NaN
# bmi__obesity_class                                          ready        NaN
# bmi__had_bariatric_surgery                                  ready        NaN
# bmi__self_reported_overweight                               ready        NaN
# bmi__self_reported_obese                                    ready        NaN
# bmi__height                                                 ready        NaN
# bmi__weight                                                 ready        NaN
# osa__curated_phenotype                                      ready        NaN
# osa__self_reported_osa                                      ready        NaN
# osa__ahi_max                                                ready        NaN
# osa__odi_max                                                ready        NaN
# osa__rdi_max                                                ready        NaN
# ckd__egfr                                                   ready        NaN
# ckd__curated_phenotype                                      ready        NaN
# ckd__blood_bun                                              ready        NaN
# ckd__acr_categories                                         ready        NaN
# ckd__gfr_categories                                         ready        NaN
# ckd__blood_creatinine                                       ready        NaN
# ckd__urine_acr                                              ready        NaN
# ckd__urine_microalbumin                                     ready        NaN
# ckd__urine_creatinine                                       ready        NaN
# ckd__self_reported_ckd                                      ready        NaN
# mafld__self_reporting                                       ready        NaN
# mafld__speed_of_sound                                       ready        NaN
# mafld__curated_phenotype                                    ready        NaN
# mafld__bloodtest_alt                                        ready        NaN
# mafld__bloodtest_alt_category                               ready        NaN
# mafld__bloodtest_ast                                        ready        NaN
# mafld__bloodtest_ast_category                               ready        NaN
# mafld__de_ritis_ratio                                       ready        NaN
# mafld__de_ritis_ratio_category                              ready        NaN
# mafld__fibrosis_4                                           ready        NaN
# mafld__fibrosis_4_category                                  ready        NaN
# diabetes__self_reported_diabetic                            ready        NaN
# diabetes__self_reported_prediabetic                         ready        NaN
# diabetes__curated_phenotype                                 ready        NaN
# diabetes__bloodtest_hba1c                                   ready        NaN
# diabetes__bloodtest_fpg                                     ready        NaN
# diabetes__cgm_ea1c                                          ready        NaN
# diabetes__cgm_hbgi                                          ready        NaN
# diabetes__cgm_mage                                          ready        NaN
# ischemic_heart_disease__curated_phenotype                   ready        NaN
# ischemic_heart_disease__self_reported_ischemic_...          ready        NaN
# ischemic_heart_disease__nitrates                            ready        NaN
# ischemic_heart_disease__st_mv_aVF                           ready        NaN
# ischemic_heart_disease__st_mv_aVL                           ready        NaN
# ischemic_heart_disease__st_mv_aVR                           ready        NaN
# ischemic_heart_disease__st_mv_I                             ready        NaN
# ischemic_heart_disease__st_mv_II                            ready        NaN
# ischemic_heart_disease__st_mv_III                           ready        NaN
# ischemic_heart_disease__st_mv_V1                            ready        NaN
# ischemic_heart_disease__st_mv_V2                            ready        NaN
# ischemic_heart_disease__st_mv_V3                            ready        NaN
# ischemic_heart_disease__st_mv_V4                            ready        NaN
# ischemic_heart_disease__st_mv_V5                            ready        NaN
# ischemic_heart_disease__st_mv_V6                            ready        NaN
# sleep_quality__curated_phenotype                            ready        NaN
# sleep_quality__sleep_index                                  ready        NaN
# sleep_quality__sleep_index_lowrisk_snoring                  ready        NaN
# sleep_quality__sleep_index_lowrisk_chronotype               ready        NaN
# sleep_quality__sleep_index_lowrisk_daytime                  ready        NaN
# sleep_quality__sleep_index_lowrisk_hours_daily              ready        NaN
# sleep_quality__sleep_index_lowrisk_insomnia                 ready        NaN
# sleep_quality__sleep_index_lowrisk_waking_morni...          ready        NaN
# sleep_quality__number_of_wakes                              ready        NaN
# sleep_quality__percent_of_deep_sleep_time                   ready        NaN
# sleep_quality__sleep_latency                                ready        NaN
# sleep_quality__total_sleep_time                             ready        NaN
# sleep_quality__total_wake_time_after_sleep_onset            ready        NaN
# sleep_quality__sleep_efficiency                             ready        NaN
# hypertension__curated_phenotype                             ready        NaN
# hypertension__self_reported_hypertension                    ready        NaN
# hypertension__sitting_blood_pressure_systolic               ready        NaN
# hypertension__sitting_blood_pressure_diastolic              ready        NaN
# hypertension__lying_blood_pressure_systolic                 ready        NaN
# hypertension__lying_blood_pressure_diastolic                ready        NaN
# hypertension__l_brachial_pressure                           ready        NaN
# hypertension__r_brachial_pressure                           ready        NaN
# hypertension__acc_aha_ranges                                ready        NaN
# hyperlipidemia__curated_phenotype                           ready        NaN
# hyperlipidemia__hypertriglyceridemia                        ready        NaN
# hyperlipidemia__hyperlipoproteinemia                        ready        NaN
# hyperlipidemia__combined_hyperlipoproteinemia               ready        NaN
# hyperlipidemia__self_reported_hypertriglyceridemia          ready        NaN
# hyperlipidemia__self_reported_hyperlipoproteinemia          ready        NaN
# hyperlipidemia__ldl_value                                   ready        NaN
# hyperlipidemia__ldl_category                                ready        NaN
# hyperlipidemia__nightingale_ldl_value                       ready        NaN
# hyperlipidemia__total_cholesterol_value                     ready        NaN
# hyperlipidemia__total_cholesterol_category                  ready        NaN
# hyperlipidemia__triglycerides_value                         ready        NaN
# hyperlipidemia__triglycerides_category                      ready        NaN
# hyperlipidemia__nightingale_triglycerides_value             ready        NaN
# hyperlipidemia__cholesterol_tg_ratio_value                  ready        NaN
# hyperlipidemia__cholesterol_tg_ratio_category               ready        NaN
# hyperlipidemia__hdl_value                                   ready        NaN
# hyperlipidemia__hdl_category                                ready        NaN
# hyperlipidemia__nightingale_hdl_value                       ready        NaN
# nmsc__curated_phenotype                                     ready        NaN
# nmsc__self_reported_nmsc                                    ready        NaN
# nmsc__self_reported_bcc                                     ready        NaN
# nmsc__self_reported_scc                                     ready        NaN
# nmsc__self_reported_and_treated_bcc                         ready        NaN
# nmsc__self_reported_and_treated_scc                         ready        NaN
# nmsc__mole_biopsy                                           ready        NaN
# endometriosis__curated_phenotype                            ready        NaN
# endometriosis__self_reported_endometriosis                  ready        NaN
# endometriosis__self_reported_and_surgery                    ready        NaN
# endometriosis__self_reported_and_premenopausal              ready        NaN
#
#                                                                feature_set  \
# tabular_field_name
# menopause__curated_phenotype                                     menopause
# menopause__is_getting_period_ques                                menopause
# menopause__menopause_age                                         menopause
# menopause__female_current_menstural_cycle                        menopause
# menopause__extra_health_females_current_mestura...               menopause
# menopause__female_last_mestural_cycle_age                        menopause
# menopause__extra_health_females_last_mestural_c...               menopause
# osteoporosis__curated_phenotype                               osteoporosis
# osteoporosis__self_reported_osteoporosis                      osteoporosis
# osteoporosis__self_reported_osteopenia                        osteoporosis
# osteoporosis__femurs_tscore_osteoporosis                      osteoporosis
# osteoporosis__femurs_tscore_osteopenia                        osteoporosis
# osteoporosis__spine_tscore_osteoporosis                       osteoporosis
# osteoporosis__spine_tscore_osteopenia                         osteoporosis
# osteoporosis__femurs_zscore_osteoporosis                      osteoporosis
# osteoporosis__count_fractures                                 osteoporosis
# osteoporosis__menopause                                       osteoporosis
# osteoporosis__sex                                             osteoporosis
# ...
# mafld__fibrosis_4                                   Both sexes    NaN
# mafld__fibrosis_4_category                          Both sexes    NaN
# diabetes__self_reported_diabetic                    Both sexes    NaN
# diabetes__self_reported_prediabetic                 Both sexes    NaN
# diabetes__curated_phenotype                         Both sexes    NaN
# diabetes__bloodtest_hba1c                           Both sexes    NaN
# diabetes__bloodtest_fpg                             Both sexes    NaN
# diabetes__cgm_ea1c                                  Both sexes    NaN
# diabetes__cgm_hbgi                                  Both sexes    NaN
# diabetes__cgm_mage                                  Both sexes    NaN
# ischemic_heart_disease__curated_phenotype           Both sexes    NaN
# ischemic_heart_disease__self_reported_ischemic_...  Both sexes    NaN
# ischemic_heart_disease__nitrates                    Both sexes    NaN
# ischemic_heart_disease__st_mv_aVF                   Both sexes    NaN
# ischemic_heart_disease__st_mv_aVL                   Both sexes    NaN
# ischemic_heart_disease__st_mv_aVR                   Both sexes    NaN
# ischemic_heart_disease__st_mv_I                     Both sexes    NaN
# ischemic_heart_disease__st_mv_II                    Both sexes    NaN
# ischemic_heart_disease__st_mv_III                   Both sexes    NaN
# ischemic_heart_disease__st_mv_V1                    Both sexes    NaN
# ischemic_heart_disease__st_mv_V2                    Both sexes    NaN
# ischemic_heart_disease__st_mv_V3                    Both sexes    NaN
# ischemic_heart_disease__st_mv_V4                    Both sexes    NaN
# ischemic_heart_disease__st_mv_V5                    Both sexes    NaN
# ischemic_heart_disease__st_mv_V6                    Both sexes    NaN
# sleep_quality__curated_phenotype                    Both sexes    NaN
# sleep_quality__sleep_index                          Both sexes    NaN
# sleep_quality__sleep_index_lowrisk_snoring          Both sexes    NaN
# sleep_quality__sleep_index_lowrisk_chronotype       Both sexes    NaN
# sleep_quality__sleep_index_lowrisk_daytime          Both sexes    NaN
# sleep_quality__sleep_index_lowrisk_hours_daily      Both sexes    NaN
# sleep_quality__sleep_index_lowrisk_insomnia         Both sexes    NaN
# sleep_quality__sleep_index_lowrisk_waking_morni...  Both sexes    NaN
# sleep_quality__number_of_wakes                      Both sexes    NaN
# sleep_quality__percent_of_deep_sleep_time           Both sexes    NaN
# sleep_quality__sleep_latency                        Both sexes    NaN
# sleep_quality__total_sleep_time                     Both sexes    NaN
# sleep_quality__total_wake_time_after_sleep_onset    Both sexes    NaN
# sleep_quality__sleep_efficiency                     Both sexes    NaN
# hypertension__curated_phenotype                     Both sexes    NaN
# hypertension__self_reported_hypertension            Both sexes    NaN
# hypertension__sitting_blood_pressure_systolic       Both sexes    NaN
# hypertension__sitting_blood_pressure_diastolic      Both sexes    NaN
# hypertension__lying_blood_pressure_systolic         Both sexes    NaN
# hypertension__lying_blood_pressure_diastolic        Both sexes    NaN
# hypertension__l_brachial_pressure                   Both sexes    NaN
# hypertension__r_brachial_pressure                   Both sexes    NaN
# hypertension__acc_aha_ranges                        Both sexes    NaN
# hyperlipidemia__curated_phenotype                   Both sexes    NaN
# hyperlipidemia__hypertriglyceridemia                Both sexes    NaN
# hyperlipidemia__hyperlipoproteinemia                Both sexes    NaN
# hyperlipidemia__combined_hyperlipoproteinemia       Both sexes    NaN
# hyperlipidemia__self_reported_hypertriglyceridemia  Both sexes    NaN
# hyperlipidemia__self_reported_hyperlipoproteinemia  Both sexes    NaN
# hyperlipidemia__ldl_value                           Both sexes    NaN
# hyperlipidemia__ldl_category                        Both sexes    NaN
# hyperlipidemia__nightingale_ldl_value               Both sexes    NaN
# hyperlipidemia__total_cholesterol_value             Both sexes    NaN
# hyperlipidemia__total_cholesterol_category          Both sexes    NaN
# hyperlipidemia__triglycerides_value                 Both sexes    NaN
# hyperlipidemia__triglycerides_category              Both sexes    NaN
# hyperlipidemia__nightingale_triglycerides_value     Both sexes    NaN
# hyperlipidemia__cholesterol_tg_ratio_value          Both sexes    NaN
# hyperlipidemia__cholesterol_tg_ratio_category       Both sexes    NaN
# hyperlipidemia__hdl_value                           Both sexes    NaN
# hyperlipidemia__hdl_category                        Both sexes    NaN
# hyperlipidemia__nightingale_hdl_value               Both sexes    NaN
# nmsc__curated_phenotype                             Both sexes    NaN
# nmsc__self_reported_nmsc                            Both sexes    NaN
# nmsc__self_reported_bcc                             Both sexes    NaN
# nmsc__self_reported_scc                             Both sexes    NaN
# nmsc__self_reported_and_treated_bcc                 Both sexes    NaN
# nmsc__self_reported_and_treated_scc                 Both sexes    NaN
# nmsc__mole_biopsy                                   Both sexes    NaN
# endometriosis__curated_phenotype                    Both sexes    NaN
# endometriosis__self_reported_endometriosis          Both sexes    NaN
# endometriosis__self_reported_and_surgery            Both sexes    NaN
# endometriosis__self_reported_and_premenopausal      Both sexes    NaN
#
#                                                     completed
# tabular_field_name
# menopause__curated_phenotype                              NaN
# menopause__is_getting_period_ques                         NaN
# menopause__menopause_age                                  NaN
# menopause__female_current_menstural_cycle                 NaN
# menopause__extra_health_females_current_mestura...        NaN
# menopause__female_last_mestural_cycle_age                 NaN
# menopause__extra_health_females_last_mestural_c...        NaN
# osteoporosis__curated_phenotype                           NaN
# osteoporosis__self_reported_osteoporosis                  NaN
# osteoporosis__self_reported_osteopenia                    NaN
# osteoporosis__femurs_tscore_osteoporosis                  NaN
# osteoporosis__femurs_tscore_osteopenia                    NaN
# osteoporosis__spine_tscore_osteoporosis                   NaN
# osteoporosis__spine_tscore_osteopenia                     NaN
# osteoporosis__femurs_zscore_osteoporosis                  NaN
# osteoporosis__count_fractures                             NaN
# osteoporosis__menopause                                   NaN
# osteoporosis__sex                                         NaN
# osteoporosis__age_at_research_stage                       NaN
# osteoporosis__M05BA                                       NaN
# osteoporosis__femur_bmd_min                               NaN
# osteoporosis__femur_neck_bmd_min                          NaN
# osteoporosis__spine_l1_l4_bmd                             NaN
# migraine__curated_phenotype                               NaN
# migraine__severe_migraine_medication                      NaN
# migraine__other_migraine_medication                       NaN
# migraine__self_reported_migraine                          NaN
# depression__curated_phenotype                             NaN
# depression__probable_recurrent_major_depression           NaN
# depression__self_reported_depression                      NaN
# depression__ibs_depression_treatment_past                 NaN
# depression__taking_anti_depressants                       NaN
# adhd__curated_phenotype                                   NaN
# adhd__self_reported_ADHD                                  NaN
# adhd__main_ADHD_medication                                NaN
# adhd__any_ADHD_medication                                 NaN
# adhd__neuroticism_value                                   NaN
# anxiety__self_reported_anxiety                            NaN
# anxiety__curated_phenotype                                NaN
# anxiety__health_mental_current_worrier                    NaN
# abdominal_adiposity__curated_phenotype                    NaN
# abdominal_adiposity__total_scan_vat_mass                  NaN
# abdominal_adiposity__total_scan_sat_mass                  NaN
# abdominal_adiposity__vat_sat_ratio                        NaN
# abdominal_adiposity__vat_index                            NaN
# abdominal_adiposity__waist_circumference                  NaN
# abdominal_adiposity__waist_to_hip_ratio                   NaN
# abdominal_adiposity__visceral_adipose_index               NaN
# bmi__curated_phenotype                                    NaN
# bmi__bmi                                                  NaN
# bmi__obesity_class                                        NaN
# bmi__had_bariatric_surgery                                NaN
# bmi__self_reported_overweight                             NaN
# bmi__self_reported_obese                                  NaN
# bmi__height                                               NaN
# bmi__weight                                               NaN
# osa__curated_phenotype                                    NaN
# osa__self_reported_osa                                    NaN
# osa__ahi_max                                              NaN
# osa__odi_max                                              NaN
# osa__rdi_max                                              NaN
# ckd__egfr                                                 NaN
# ckd__curated_phenotype                                    NaN
# ckd__blood_bun                                            NaN
# ckd__acr_categories                                       NaN
# ckd__gfr_categories                                       NaN
# ckd__blood_creatinine                                     NaN
# ckd__urine_acr                                            NaN
# ckd__urine_microalbumin                                   NaN
# ckd__urine_creatinine                                     NaN
# ckd__self_reported_ckd                                    NaN
# mafld__self_reporting                                     NaN
# mafld__speed_of_sound                                     NaN
# mafld__curated_phenotype                                  NaN
# mafld__bloodtest_alt                                      NaN
# mafld__bloodtest_alt_category                             NaN
# mafld__bloodtest_ast                                      NaN
# mafld__bloodtest_ast_category                             NaN
# mafld__de_ritis_ratio                                     NaN
# mafld__de_ritis_ratio_category                            NaN
# mafld__fibrosis_4                                         NaN
# mafld__fibrosis_4_category                                NaN
# diabetes__self_reported_diabetic                          NaN
# diabetes__self_reported_prediabetic                       NaN
# diabetes__curated_phenotype                               NaN
# diabetes__bloodtest_hba1c                                 NaN
# diabetes__bloodtest_fpg                                   NaN
# diabetes__cgm_ea1c                                        NaN
# diabetes__cgm_hbgi                                        NaN
# diabetes__cgm_mage                                        NaN
# ischemic_heart_disease__curated_phenotype                 NaN
# ischemic_heart_disease__self_reported_ischemic_...        NaN
# ischemic_heart_disease__nitrates                          NaN
# ischemic_heart_disease__st_mv_aVF                         NaN
# ischemic_heart_disease__st_mv_aVL                         NaN
# ischemic_heart_disease__st_mv_aVR                         NaN
# ischemic_heart_disease__st_mv_I                           NaN
# ischemic_heart_disease__st_mv_II                          NaN
# ischemic_heart_disease__st_mv_III                         NaN
# ischemic_heart_disease__st_mv_V1                          NaN
# ischemic_heart_disease__st_mv_V2                          NaN
# ischemic_heart_disease__st_mv_V3                          NaN
# ischemic_heart_disease__st_mv_V4                          NaN
# ischemic_heart_disease__st_mv_V5                          NaN
# ischemic_heart_disease__st_mv_V6                          NaN
# sleep_quality__curated_phenotype                          NaN
# sleep_quality__sleep_index                                NaN
# sleep_quality__sleep_index_lowrisk_snoring                NaN
# sleep_quality__sleep_index_lowrisk_chronotype             NaN
# sleep_quality__sleep_index_lowrisk_daytime                NaN
# sleep_quality__sleep_index_lowrisk_hours_daily            NaN
# sleep_quality__sleep_index_lowrisk_insomnia               NaN
# sleep_quality__sleep_index_lowrisk_waking_morni...        NaN
# sleep_quality__number_of_wakes                            NaN
# sleep_quality__percent_of_deep_sleep_time                 NaN
# sleep_quality__sleep_latency                              NaN
# sleep_quality__total_sleep_time                           NaN
# sleep_quality__total_wake_time_after_sleep_onset          NaN
# sleep_quality__sleep_efficiency                           NaN
# hypertension__curated_phenotype                           NaN
# hypertension__self_reported_hypertension                  NaN
# hypertension__sitting_blood_pressure_systolic             NaN
# hypertension__sitting_blood_pressure_diastolic            NaN
# hypertension__lying_blood_pressure_systolic               NaN
# hypertension__lying_blood_pressure_diastolic              NaN
# hypertension__l_brachial_pressure                         NaN
# hypertension__r_brachial_pressure                         NaN
# hypertension__acc_aha_ranges                              NaN
# hyperlipidemia__curated_phenotype                         NaN
# hyperlipidemia__hypertriglyceridemia                      NaN
# hyperlipidemia__hyperlipoproteinemia                      NaN
# hyperlipidemia__combined_hyperlipoproteinemia             NaN
# hyperlipidemia__self_reported_hypertriglyceridemia        NaN
# hyperlipidemia__self_reported_hyperlipoproteinemia        NaN
# hyperlipidemia__ldl_value                                 NaN
# hyperlipidemia__ldl_category                              NaN
# hyperlipidemia__nightingale_ldl_value                     NaN
# hyperlipidemia__total_cholesterol_value                   NaN
# hyperlipidemia__total_cholesterol_category                NaN
# hyperlipidemia__triglycerides_value                       NaN
# hyperlipidemia__triglycerides_category                    NaN
# hyperlipidemia__nightingale_triglycerides_value           NaN
# hyperlipidemia__cholesterol_tg_ratio_value                NaN
# hyperlipidemia__cholesterol_tg_ratio_category             NaN
# hyperlipidemia__hdl_value                                 NaN
# hyperlipidemia__hdl_category                              NaN
# hyperlipidemia__nightingale_hdl_value                     NaN
# nmsc__curated_phenotype                                   NaN
# nmsc__self_reported_nmsc                                  NaN
# nmsc__self_reported_bcc                                   NaN
# nmsc__self_reported_scc                                   NaN
# nmsc__self_reported_and_treated_bcc                       NaN
# nmsc__self_reported_and_treated_scc                       NaN
# nmsc__mole_biopsy                                         NaN
# endometriosis__curated_phenotype                          NaN
# endometriosis__self_reported_endometriosis                NaN
# endometriosis__self_reported_and_surgery                  NaN
# endometriosis__self_reported_and_premenopausal            NaN
#
# [158 rows x 32 columns]
