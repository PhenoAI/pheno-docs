# %% [raw]
# ---
# output-file: 029-nightingale_metabolomics.html
# title: 029-nightingale_metabolomics
# ---

# %% [markdown]
# # Nightingale Metabolomics
#
# The dataset, derived from Nightingale Health's metabolic profiling of blood serum samples, presents an extensive array of metabolites, encapsulating lipids, fatty acids, amino acids, and various low-molecular-weight metabolites. Utilizing innovative Nuclear Magnetic Resonance (NMR) technology, the dataset unveils a spectrum of 250 biomarkers, 39 of which are clinically validated, offering a profound insight into the metabolic mechanisms underlying health and disease.
#
# ### Data availability:
#
# The information is stored in 2 parquet file:
# 1. Results - nightingale_metabolomics.parquet - quantification of metabolites in blood sample.
# 2. Tags per Biomarker - tags_per_biomarker.parquet - categorical tags per metabolite per sample
#
# As of 2024-02-01, the dataset contains 1700 participants who were analyzed.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('nightingale_metabolomics')
pl
# Out:
# PhenoLoader for nightingale_metabolomics with
# 505 fields
# 3 tables: ['nightingale_metabolomics', 'tags_per_biomarker', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                       folder_id               feature_set  \
# tabular_field_name
# collection_date              29  nightingale_metabolomics
# timezone                     29  nightingale_metabolomics
# collection_timestamp         29  nightingale_metabolomics
# total_c                      29  nightingale_metabolomics
# non_hdl_c                    29  nightingale_metabolomics
# ...                         ...                       ...
# s_hdl_pl_pct_tag             29          bimarker_qc_tags
# s_hdl_c_pct_tag              29          bimarker_qc_tags
# s_hdl_ce_pct_tag             29          bimarker_qc_tags
# s_hdl_fc_pct_tag             29          bimarker_qc_tags
# s_hdl_tg_pct_tag             29          bimarker_qc_tags
#
#                                       field_string  \
# tabular_field_name
# collection_date       Collection date (YYYY-MM-DD)
# timezone                                  Timezone
# collection_timestamp          Collection timestamp
# total_c                                    Total-C
# non_hdl_c                                non-HDL-C
# ...                                            ...
# s_hdl_pl_pct_tag                    S-HDL-PL % Tag
# s_hdl_c_pct_tag                      S-HDL-C % Tag
# s_hdl_ce_pct_tag                    S-HDL-CE % Tag
# s_hdl_fc_pct_tag                    S-HDL-FC % Tag
# s_hdl_tg_pct_tag                    S-HDL-TG % Tag
#
#                                   description_string              field_type  \
# tabular_field_name
# collection_date         Collection date (YYYY-MM-DD)                    Date
# timezone              Timezone for timestamp columns    Categorical (single)
# collection_timestamp            Collection timestamp                Datetime
# total_c                            Total cholesterol              Continuous
# non_hdl_c              Total cholesterol minus HDL-C              Continuous
# ...                                              ...                     ...
# s_hdl_pl_pct_tag                      S-HDL-PL % Tag  Categorical (multiple)
# s_hdl_c_pct_tag                        S-HDL-C % Tag  Categorical (multiple)
# s_hdl_ce_pct_tag                      S-HDL-CE % Tag  Categorical (multiple)
# s_hdl_fc_pct_tag                      S-HDL-FC % Tag  Categorical (multiple)
# s_hdl_tg_pct_tag                      S-HDL-TG % Tag  Categorical (multiple)
#
#                       bulk_dictionary  bulk_file_extension  \
# tabular_field_name
# collection_date                   NaN                  NaN
# timezone                          NaN                  NaN
# collection_timestamp              NaN                  NaN
# total_c                           NaN                  NaN
# non_hdl_c                         NaN                  NaN
# ...                               ...                  ...
# s_hdl_pl_pct_tag                  NaN                  NaN
# s_hdl_c_pct_tag                   NaN                  NaN
# s_hdl_ce_pct_tag                  NaN                  NaN
# s_hdl_fc_pct_tag                  NaN                  NaN
# s_hdl_tg_pct_tag                  NaN                  NaN
#
#                                                       relative_location  \
# tabular_field_name
# collection_date       nightingale_metabolomics/nightingale_metabolom...
# timezone              nightingale_metabolomics/nightingale_metabolom...
# collection_timestamp  nightingale_metabolomics/nightingale_metabolom...
# total_c               nightingale_metabolomics/nightingale_metabolom...
# non_hdl_c             nightingale_metabolomics/nightingale_metabolom...
# ...                                                                 ...
# s_hdl_pl_pct_tag      nightingale_metabolomics/tags_per_biomarker.pa...
# s_hdl_c_pct_tag       nightingale_metabolomics/tags_per_biomarker.pa...
# s_hdl_ce_pct_tag      nightingale_metabolomics/tags_per_biomarker.pa...
# s_hdl_fc_pct_tag      nightingale_metabolomics/tags_per_biomarker.pa...
# s_hdl_tg_pct_tag      nightingale_metabolomics/tags_per_biomarker.pa...
#
#                      data_coding  stability  ...       sexed     array debut  \
# tabular_field_name                           ...
# collection_date              NaN        NaN  ...  Both sexes    Single   NaN
# timezone                  001_03        NaN  ...  Both sexes    Single   NaN
# collection_timestamp         NaN        NaN  ...  Both sexes    Single   NaN
# total_c                      NaN        NaN  ...  Both sexes    Single   NaN
# non_hdl_c                    NaN        NaN  ...  Both sexes    Single   NaN
# ...                          ...        ...  ...         ...       ...   ...
# s_hdl_pl_pct_tag           P2310        NaN  ...  Both sexes  Multiple   NaN
# s_hdl_c_pct_tag            P2310        NaN  ...  Both sexes  Multiple   NaN
# s_hdl_ce_pct_tag           P2310        NaN  ...  Both sexes  Multiple   NaN
# s_hdl_fc_pct_tag           P2310        NaN  ...  Both sexes  Multiple   NaN
# s_hdl_tg_pct_tag           P2310        NaN  ...  Both sexes  Multiple   NaN
#
#                      completed transformation  list_of_tags    pandas_dtype  \
# tabular_field_name
# collection_date            NaN            NaN           NaN  datetime64[ns]
# timezone                   NaN            NaN           NaN        category
# collection_timestamp       NaN            NaN           NaN  datetime64[ns]
# total_c                    NaN            NaN           NaN           float
# non_hdl_c                  NaN            NaN           NaN           float
# ...                        ...            ...           ...             ...
# s_hdl_pl_pct_tag           NaN            NaN           NaN          object
# s_hdl_c_pct_tag            NaN            NaN           NaN          object
# s_hdl_ce_pct_tag           NaN            NaN           NaN          object
# s_hdl_fc_pct_tag           NaN            NaN           NaN          object
# s_hdl_tg_pct_tag           NaN            NaN           NaN          object
#
#                       nightingale_metabolomics__biomarker_group  \
# tabular_field_name
# collection_date                                             NaN
# timezone                                                    NaN
# collection_timestamp                                        NaN
# total_c                                             Cholesterol
# non_hdl_c                                           Cholesterol
# ...                                                         ...
# s_hdl_pl_pct_tag                                            NaN
# s_hdl_c_pct_tag                                             NaN
# s_hdl_ce_pct_tag                                            NaN
# s_hdl_fc_pct_tag                                            NaN
# s_hdl_tg_pct_tag                                            NaN
#
#                       nightingale_metabolomics__biomarker_subgroup  \
# tabular_field_name
# collection_date                                                NaN
# timezone                                                       NaN
# collection_timestamp                                           NaN
# total_c                                                        NaN
# non_hdl_c                                                      NaN
# ...                                                            ...
# s_hdl_pl_pct_tag                                               NaN
# s_hdl_c_pct_tag                                                NaN
# s_hdl_ce_pct_tag                                               NaN
# s_hdl_fc_pct_tag                                               NaN
# s_hdl_tg_pct_tag                                               NaN
#
#                      nightingale_metabolomics__original_name
# tabular_field_name
# collection_date                                          NaN
# timezone                                                 NaN
# collection_timestamp                                     NaN
# total_c                                              Total_C
# non_hdl_c                                          non_HDL_C
# ...                                                      ...
# s_hdl_pl_pct_tag                                         NaN
# s_hdl_c_pct_tag                                          NaN
# s_hdl_ce_pct_tag                                         NaN
# s_hdl_fc_pct_tag                                         NaN
# s_hdl_tg_pct_tag                                         NaN
#
# [503 rows x 23 columns]
