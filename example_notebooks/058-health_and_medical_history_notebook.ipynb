# %% [markdown]
# # Health and medical history
#
# ### Description
#
# Health and medical history data provides comprehensive insights into an individual's past and present medical conditions, treatments, surgeries, and overall health status. This data includes personal health details such as chronic illnesses, medications, hospitalizations, and surgical procedures, which help in assessing risk factors and understanding disease progression over time.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes information about a participant's health and medical history, captured through two lifestyle surveys.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 2 parquet files: `ukbb.parquet` and `initial_medical.parquet`
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/058-health_and_medical_history.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/58)

# %%
# %load_ext autoreload
# %autoreload 2

from pheno_utils import PhenoLoader
import pandas as pd
import random

# %%
pl = PhenoLoader('health_and_medical_history', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for health_and_medical_history with
# 71 fields
# 3 tables: ['ukbb', 'initial_medical', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict.head()
# Out:
#                                     folder_id feature_set  \
# tabular_field_name
# collection_timestamp                       58        ukbb
# collection_date                            58        ukbb
# timezone                                   58        ukbb
# health_general_rating                      58        ukbb
# health_general_dissability_illness         58        ukbb
#
#                                                                       field_string  \
# tabular_field_name
# collection_timestamp                                          Collection timestamp
# collection_date                                                    Collection date
# timezone                                                                  Timezone
# health_general_rating                                        Overall health rating
# health_general_dissability_illness  Long-standing illness, disability or infirmity
#
#                                                           relative_location  \
# tabular_field_name
# collection_timestamp                health_and_medical_history/ukbb.parquet
# collection_date                     health_and_medical_history/ukbb.parquet
# timezone                            health_and_medical_history/ukbb.parquet
# health_general_rating               health_and_medical_history/ukbb.parquet
# health_general_dissability_illness  health_and_medical_history/ukbb.parquet
#
#                                     bulk_file_extension  bulk_dictionary  \
# tabular_field_name
# collection_timestamp                                NaN              NaN
# collection_date                                     NaN              NaN
# timezone                                            NaN              NaN
# health_general_rating                               NaN              NaN
# health_general_dissability_illness                  NaN              NaN
#
#                                                                    description_string  \
# tabular_field_name
# collection_timestamp                                             Collection timestamp
# collection_date                                                       Collection date
# timezone                                                                     Timezone
# health_general_rating               In general how would you rate your overall hea...
# health_general_dissability_illness  Do you have any long-standing illness, disabil...
#
#                                               field_type   array  \
# tabular_field_name
# collection_timestamp                            Datetime  Single
# collection_date                                     Date  Single
# timezone                                            Text  Single
# health_general_rating               Categorical (single)  Single
# health_general_dissability_illness  Categorical (single)  Single
#
#                                                       pandas_dtype stability  \
# tabular_field_name
# collection_timestamp                datetime64[ns, Asia/Jerusalem]  Accruing
# collection_date                                     datetime64[ns]  Accruing
# timezone                                                  category  Accruing
# health_general_rating                                          int  Accruing
# health_general_dissability_illness                             int  Accruing
#
#                                    units  sampling_rate           strata  \
# tabular_field_name
# collection_timestamp                 NaN            NaN  Collection time
# collection_date                      NaN            NaN  Collection time
# timezone                             NaN            NaN  Collection time
# health_general_rating                NaN            NaN          Primary
# health_general_dissability_illness   NaN            NaN          Primary
#
#                                          sexed     debut  completed  \
# tabular_field_name
# collection_timestamp                Both sexes  1/9/2019        NaN
# collection_date                     Both sexes  1/9/2019        NaN
# timezone                            Both sexes  1/9/2019        NaN
# health_general_rating               Both sexes  1/9/2019        NaN
# health_general_dissability_illness  Both sexes  1/9/2019        NaN
#
#                                    data_coding
# tabular_field_name
# collection_timestamp                       NaN
# collection_date                            NaN
# timezone                                   NaN
# health_general_rating                   100508
# health_general_dissability_illness      100349

# %%
pl.dfs['initial_medical'].head()
# Out:
#                                                  oralheatlh_bleeding_gums  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                              Often
# 5027574288     10k    00_00_visit    0                                 No
# 7783260382     10k    00_00_visit    0                                NaN
# 1178277844     10k    00_00_visit    0                             Rarely
# 1622660825     10k    00_00_visit    0                                NaN
#
#                                                  oralheatlh_abscess_or_gingivitis  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                     Rarely
# 5027574288     10k    00_00_visit    0                                        NaN
# 7783260382     10k    00_00_visit    0                                        NaN
# 1178277844     10k    00_00_visit    0                                      Never
# 1622660825     10k    00_00_visit    0                                        NaN
#
#                                                  oralheatlh_antibiotics_for_gingivitis  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                           Never
# 5027574288     10k    00_00_visit    0                                             NaN
# 7783260382     10k    00_00_visit    0                                             NaN
# 1178277844     10k    00_00_visit    0                                           Never
# 1622660825     10k    00_00_visit    0                                             NaN
#
#                                                    oralheatlh_bad_breath  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            Do not have bad breath
# 5027574288     10k    00_00_visit    0                               NaN
# 7783260382     10k    00_00_visit    0                               NaN
# 1178277844     10k    00_00_visit    0                       Do not know
# 1622660825     10k    00_00_visit    0                               NaN
#
#                                                             oralheatlh_teeth_mobility_lately  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                    No
# 5027574288     10k    00_00_visit    0            Slight mobility in a small number of teeth
# 7783260382     10k    00_00_visit    0                                                   NaN
# 1178277844     10k    00_00_visit    0                                                    No
# 1622660825     10k    00_00_visit    0                                                   NaN
#
#                                                   eye_health_eyeglasses_age  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                            14.831559
# 5027574288     10k    00_00_visit    0                            14.852326
# 7783260382     10k    00_00_visit    0                                  NaN
# 1178277844     10k    00_00_visit    0                         -1498.691747
# 1622660825     10k    00_00_visit    0                                  NaN
#
#                                                   eye_health_decreased_eyesight_age  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                          NaN
# 5027574288     10k    00_00_visit    0                                 -1499.753959
# 7783260382     10k    00_00_visit    0                                          NaN
# 1178277844     10k    00_00_visit    0                                          NaN
# 1622660825     10k    00_00_visit    0                                          NaN
#
#                                                   eye_health_ona_age  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                           NaN
# 5027574288     10k    00_00_visit    0                           NaN
# 7783260382     10k    00_00_visit    0                           NaN
# 1178277844     10k    00_00_visit    0                           NaN
# 1622660825     10k    00_00_visit    0                           NaN
#
#                                                   eye_health_conjunctivitis_age  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                      NaN
# 5027574288     10k    00_00_visit    0                                      NaN
# 7783260382     10k    00_00_visit    0                                      NaN
# 1178277844     10k    00_00_visit    0                             -1499.592424
# 1622660825     10k    00_00_visit    0                             -1499.986679
#
#                                                   eye_health_surgery_improve_vision_age
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                     -1499.006824
# 5027574288     10k    00_00_visit    0                                              NaN
# 7783260382     10k    00_00_visit    0                                              NaN
# 1178277844     10k    00_00_visit    0                                        27.904999
# 1622660825     10k    00_00_visit    0                                              NaN

# %% [markdown]
# ## Data coding
# A data-coding is a mapping between the actual data and the values used to represent it within the database for categorical features.

# %%
df_codes = pl.data_codings
df_codes.head()
# Out:
#   code_number  coding                                            english  \
# 0      001_03       0                                     asia/jerusalem
# 1      062_02       1                                             BRCA-1
# 2      062_02       2                                             BRCA-2
# 3      062_02      -1                                        Do not know
# 4      062_03       1  A relative of mine got breast, ovarian, or pro...
#
#                                               hebrew  answer_field_name  \
# 0                                          זמן ישראל                NaN
# 1                                             BRCA-1        brca_type_1
# 2                                             BRCA-2        brca_type_2
# 3                                          לא יודע/ת        brca_type_3
# 4  קרוב/ת משפחה חלה/תה בסרטן השד, השחלה, או הערמו...  brca_indication_1
#
#         sexed ukbb_compatible  ukbb_similar_coding scripting_instruction  \
# 0         NaN           False                  NaN                   NaN
# 1  Both sexes             NaN                  NaN                   NaN
# 2  Both sexes             NaN                  NaN                   NaN
# 3  Both sexes             NaN                  NaN                  NMUL
# 4  Both sexes             NaN                  NaN                   NaN
#
#   description notes
# 0    Timezone   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN

# %% [markdown]
# Each column represents a single question.
# The type of the question (integer, or category with single/multiple choice) can be found in the data dictionary.

# %%
pl.dict['field_type'].value_counts()
# Out:
# field_type
# Categorical (single)      51
# Integer                   14
# Categorical (multiple)     4
# Text                       3
# Date                       2
# Datetime                   2
# Name: count, dtype: int64

# %% [markdown]
# ### Numeric questions

# %% [markdown]
# For numeric questions the answers are the numbers entered when filling the survey

# %%
pl.dict[pl.dict['field_type'] == 'Integer'].head()
# Out:
#                                          folder_id feature_set  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age          58        ukbb
# health_eyes_diabetes_eye_start_age              58        ukbb
# health_eyes_glaucoma_eye_start_age              58        ukbb
# health_eyes_injury_trauma_eye_start_age         58        ukbb
# health_eyes_cataract_eye_start_age              58        ukbb
#
#                                                                               field_string  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age       Age started wearing glasses or contact lenses
# health_eyes_diabetes_eye_start_age         Age when diabetes-related eye disease diagnosed
# health_eyes_glaucoma_eye_start_age                                  Age glaucoma diagnosed
# health_eyes_injury_trauma_eye_start_age  Age when loss of vision due to injury or traum...
# health_eyes_cataract_eye_start_age                                  Age cataract diagnosed
#
#                                                                relative_location  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age   health_and_medical_history/ukbb.parquet
# health_eyes_diabetes_eye_start_age       health_and_medical_history/ukbb.parquet
# health_eyes_glaucoma_eye_start_age       health_and_medical_history/ukbb.parquet
# health_eyes_injury_trauma_eye_start_age  health_and_medical_history/ukbb.parquet
# health_eyes_cataract_eye_start_age       health_and_medical_history/ukbb.parquet
#
#                                          bulk_file_extension  bulk_dictionary  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age                   NaN              NaN
# health_eyes_diabetes_eye_start_age                       NaN              NaN
# health_eyes_glaucoma_eye_start_age                       NaN              NaN
# health_eyes_injury_trauma_eye_start_age                  NaN              NaN
# health_eyes_cataract_eye_start_age                       NaN              NaN
#
#                                                                         description_string  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age   What age did you first start to wear glasses o...
# health_eyes_diabetes_eye_start_age       What was your age when diabetes related eye di...
# health_eyes_glaucoma_eye_start_age       What was your age when glaucoma was first diag...
# health_eyes_injury_trauma_eye_start_age  What was your age when injury or trauma result...
# health_eyes_cataract_eye_start_age       What was your age when a cataract was first di...
#
#                                         field_type   array pandas_dtype  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age     Integer  Single          int
# health_eyes_diabetes_eye_start_age         Integer  Single          int
# health_eyes_glaucoma_eye_start_age         Integer  Single          int
# health_eyes_injury_trauma_eye_start_age    Integer  Single          int
# health_eyes_cataract_eye_start_age         Integer  Single          int
#
#                                         stability  units  sampling_rate  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age   Accruing  Years            NaN
# health_eyes_diabetes_eye_start_age       Accruing  Years            NaN
# health_eyes_glaucoma_eye_start_age       Accruing  Years            NaN
# health_eyes_injury_trauma_eye_start_age  Accruing  Years            NaN
# health_eyes_cataract_eye_start_age       Accruing  Years            NaN
#
#                                           strata       sexed     debut  \
# tabular_field_name
# health_eyes_glasses_contacts_start_age   Primary  Both sexes  1/9/2019
# health_eyes_diabetes_eye_start_age       Primary  Both sexes  1/9/2019
# health_eyes_glaucoma_eye_start_age       Primary  Both sexes  1/9/2019
# health_eyes_injury_trauma_eye_start_age  Primary  Both sexes  1/9/2019
# health_eyes_cataract_eye_start_age       Primary  Both sexes  1/9/2019
#
#                                          completed data_coding
# tabular_field_name
# health_eyes_glasses_contacts_start_age         NaN         NaN
# health_eyes_diabetes_eye_start_age             NaN         NaN
# health_eyes_glaucoma_eye_start_age             NaN         NaN
# health_eyes_injury_trauma_eye_start_age        NaN         NaN
# health_eyes_cataract_eye_start_age             NaN         NaN

# %%
# filter out baseline visit
col = 'health_eyes_glasses_contacts_start_age'

df = pl[[col, 'age', 'sex', 'collection_date']].loc[:,:,"00_00_visit",:,:]

df.head()
# Out:
# /home/ec2-user/miniconda3/lib/python3.11/site-packages/pheno_utils/pheno_loader.py:460: UserWarning: Fields not found: ['collection_date']
#   warnings.warn(f'Fields not found: {not_found}')
#                                    health_eyes_glasses_contacts_start_age  \
# participant_id cohort array_index
# 5516424321     10k    0                                                16
# 5027574288     10k    0                                                15
# 7783260382     10k    0                                                 4
# 1178277844     10k    0                                                 0
# 1622660825     10k    0                                                 3
#
#                                          age     sex
# participant_id cohort array_index
# 5516424321     10k    0            54.447672  Female
# 5027574288     10k    0            54.169913    Male
# 7783260382     10k    0            45.892093    Male
# 1178277844     10k    0            44.435100  Female
# 1622660825     10k    0            44.621536    Male

# %%
from pheno_utils.age_reference_plots import GenderAgeRefPlot

gender_refplots = GenderAgeRefPlot(df.dropna(subset=[col,"sex", "age"]), col, age_col="age")
gender_refplots.plot()

# %% [markdown]
# ### Categorical single choice questions

# %% [markdown]
# For categorical qustions, answers are coded according to the data coding. The automatic setting for PhenoLoader shows the values in english.

# %%
single = pl.dict[pl.dict['field_type'] == 'Categorical (single)'].index.values.tolist()
# Select a random numeric question
single_question = random.choice(single)

pl[single_question][single_question].value_counts()
# Out:
# oralheatlh_antibiotics_for_gingivitis
# Never     267
# Rarely     36
# Name: count, dtype: int64

# %% [markdown]
# To view the data codings you can set the preferred_language to 'coding' in PhenoLoader function.

# %%
pl = PhenoLoader('health_and_medical_history', preferred_language='coding', base_path='s3://pheno-synthetic-data/data')

# %% [markdown]
# To change the representation of the answers, we can use the function tranform_answers from pheno_utils.questionnaires_handler

# %%
from pheno_utils.questionnaires_handler import transform_answers

# %% [markdown]
# Transorm to English

# %%
tranformed_english = transform_answers(single_question, pl[single_question][single_question], transform_from='Coding', transform_to='English', dict_df=pl.dict, mapping_df=df_codes)
tranformed_english.value_counts()
# Out:
# oralheatlh_antibiotics_for_gingivitis
# Never     267
# Rarely     36
# Name: count, dtype: int64

# %% [markdown]
# ### Categorical multiple choice questions

# %% [markdown]
# Catrgorical multiple choice questions are coded in the same way as categorical single questions, but are saved in a list in each row.

# %%
multiple = pl.dict[pl.dict['field_type'] == 'Categorical (multiple)'].index.values.tolist()
# Select a random numeric question
multiple_question = random.choice(multiple)

if isinstance(pl.dict.loc[multiple_question]['data_coding'], pd.Series):
    code = pl.dict.loc[multiple_question]['data_coding'][0]
else:
    code = pl.dict.loc[multiple_question]['data_coding']


    

tranformed_english = transform_answers(multiple_question, pl[multiple_question][multiple_question], transform_from='coding', transform_to='english', 
                                     dict_df=pl.dict, mapping_df=df_codes)

# %%
from collections import Counter
# Flatten the list of lists into a single list
flattened = [item for sublist in tranformed_english.dropna() for item in sublist]

# Count the frequency of each answer
answer_counts = Counter(flattened)

# Display the counts
print(answer_counts)
# Out:
# Counter({'Toothache': 162, 'Bleeding gums': 76, 'Painful gums': 70, 'Mouth ulcers': 40, 'Dentures': 38, 'Prefer not to answer': 36, 'Loose teeth': 10})
