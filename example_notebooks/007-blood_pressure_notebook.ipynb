# %% [markdown]
# # Blood pressure dataset
#
# ### Description
#
# Blood pressure is the measurement of the force exerted against the walls of the arteries as blood flows through them. Blood pressure is recorded as two values: systolic pressure (the maximum arterial pressure during left ventricular contraction) and diastolic pressure (the minimum arterial pressure during left ventricular relaxation).
#
# ### Introduction
#
# Hypertension, or elevated blood pressure, is a significant risk factor for cardiovascular disease and cerebrovascular events, contributing substantially to global mortality and morbidity. Chronic hypertension is characterized by persistently elevated arterial pressure, which increases cardiac workload and can lead to cardiovascular complications. Conversely, hypotension, or abnormally low blood pressure, can be equally detrimental. Severe hypotension may result in inadequate perfusion of vital organs, potentially leading to insufficient oxygen and nutrient delivery, and in extreme cases, progressing to circulatory shock, a life-threatening condition.
#
# Blood pressure measurement can be performed in a variety of settings, including hospitals, clinics, and even at home, using an automated or manual sphygmomanometer. Blood pressure measurement can be used to monitor the effectiveness of treatment interventions, such as lifestyle changes. The goal of treatment is to achieve and maintain target blood pressure levels, which are generally lower for individuals at higher risk for cardiovascular disease.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Blood pressure is measured using an OMRON Blood Pressure Monitor HEM-RML31 device and an appropriately sized cuff. Multiple blood pressure readings are done during the visit. For each blood pressure reading, three measurements are taken: systolic pressure, diastolic pressure, and average heart rate. The participant is asked to avoid caffeine, exercise and smoking at least 30 minutes before the measurement. The measurement is taken on the left arm if possible. The cuff size is based on the arm circumference.
#
# The participant is seated for 5 minutes, after which the first measurement is taken. Repeat a second measurement after 2 minutes. The participant then lies down for 5 minutes and the lying blood pressure reading is taken. The participant then stands up, slowly. The first standing reading is taken after 1 minute of standing and the next reading after 3 minutes of standing. The participant is asked to report about dizziness on standing up.
#
# ![image alt](data:image/png;base64,...)
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `blood_pressure.parquet`
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/007-blood_pressure.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/7)

# %%
# %load_ext autoreload
# %autoreload 2

from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('blood_pressure', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for blood_pressure with
# 22 fields
# 2 tables: ['blood_pressure', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict.head()
# Out:
#                                                     field_string  \
# tabular_field_name
# collection_date                     Collection date (YYYY-MM-DD)
# collection_timestamp                        Collection timestamp
# timezone                                                Timezone
# lying_blood_pressure_diastolic    Lying diastolic blood pressure
# lying_blood_pressure_pulse_rate  Lying blood pressure pulse rate
#
#                                                    description_string  \
# tabular_field_name
# collection_date                          Collection date (YYYY-MM-DD)
# collection_timestamp                             Collection timestamp
# timezone                                                     Timezone
# lying_blood_pressure_diastolic   Lying diastolic blood pressure value
# lying_blood_pressure_pulse_rate       Lying blood pressure pulse rate
#
#                                  folder_id     feature_set  field_type  \
# tabular_field_name
# collection_date                          7  blood_pressure        Date
# collection_timestamp                     7  blood_pressure    Datetime
# timezone                                 7  blood_pressure  Continuous
# lying_blood_pressure_diastolic           7  blood_pressure  Continuous
# lying_blood_pressure_pulse_rate          7  blood_pressure  Continuous
#
#                                           strata data_coding   array  \
# tabular_field_name
# collection_date                  Collection time         NaN  Single
# collection_timestamp             Collection time         NaN  Single
# timezone                         Collection time         NaN  Single
# lying_blood_pressure_diastolic           Primary         NaN  Single
# lying_blood_pressure_pulse_rate          Primary         NaN  Single
#
#                                                    pandas_dtype  \
# tabular_field_name
# collection_date                                  datetime64[ns]
# collection_timestamp             datetime64[ns, Asia/Jerusalem]
# timezone                                                 string
# lying_blood_pressure_diastolic                            float
# lying_blood_pressure_pulse_rate                           float
#
#                                  bulk_file_extension  \
# tabular_field_name
# collection_date                                  NaN
# collection_timestamp                             NaN
# timezone                                         NaN
# lying_blood_pressure_diastolic                   NaN
# lying_blood_pressure_pulse_rate                  NaN
#
#                                                      relative_location units  \
# tabular_field_name
# collection_date                  blood_pressure/blood_pressure.parquet  Time
# collection_timestamp             blood_pressure/blood_pressure.parquet  Time
# timezone                         blood_pressure/blood_pressure.parquet   NaN
# lying_blood_pressure_diastolic   blood_pressure/blood_pressure.parquet  mmHg
# lying_blood_pressure_pulse_rate  blood_pressure/blood_pressure.parquet   bpm
#
#                                  bulk_dictionary  sampling_rate  \
# tabular_field_name
# collection_date                              NaN            NaN
# collection_timestamp                         NaN            NaN
# timezone                                     NaN            NaN
# lying_blood_pressure_diastolic               NaN            NaN
# lying_blood_pressure_pulse_rate              NaN            NaN
#
#                                  transformation  \
# tabular_field_name
# collection_date                             NaN
# collection_timestamp                        NaN
# timezone                                    NaN
# lying_blood_pressure_diastolic              NaN
# lying_blood_pressure_pulse_rate             NaN
#
#                                                       list_of_tags stability  \
# tabular_field_name
# collection_date                  Blood pressure, Physical measures  Accruing
# collection_timestamp             Blood pressure, Physical measures  Accruing
# timezone                         Blood pressure, Physical measures  Accruing
# lying_blood_pressure_diastolic   Blood pressure, Physical measures  Accruing
# lying_blood_pressure_pulse_rate  Blood pressure, Physical measures  Accruing
#
#                                       sexed       debut  completed
# tabular_field_name
# collection_date                  Both sexes  2019-01-29        NaN
# collection_timestamp             Both sexes  2019-01-29        NaN
# timezone                         Both sexes  2019-01-29        NaN
# lying_blood_pressure_diastolic   Both sexes  2019-01-29        NaN
# lying_blood_pressure_pulse_rate  Both sexes  2019-01-29        NaN

# %%
pl.dfs['blood_pressure'].head()
# Out:
#                                                                collection_date  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0           2022-07-12 05:07:52.649106944
# 5027574288     10k    00_00_visit    0           2022-08-21 02:46:34.963596032
# 7783260382     10k    00_00_visit    0           2022-11-06 05:49:33.148675072
# 1178277844     10k    00_00_visit    0           2022-09-02 06:09:06.315015936
# 1622660825     10k    00_00_visit    0           2022-07-10 06:03:48.797548032
#
#                                                           collection_timestamp  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0           2022-07-15 14:14:36.300013568
# 5027574288     10k    00_00_visit    0           2022-08-11 15:43:31.747321856
# 7783260382     10k    00_00_visit    0           2022-11-03 03:32:39.260837120
# 1178277844     10k    00_00_visit    0           2022-08-23 07:57:30.151231744
# 1622660825     10k    00_00_visit    0           2022-07-17 23:19:32.042750976
#
#                                                         timezone  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            asia/jerusalem
# 5027574288     10k    00_00_visit    0            asia/jerusalem
# 7783260382     10k    00_00_visit    0            asia/jerusalem
# 1178277844     10k    00_00_visit    0            asia/jerusalem
# 1622660825     10k    00_00_visit    0            asia/jerusalem
#
#                                                   lying_blood_pressure_diastolic  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                
\
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                            116.864380
# 5027574288     10k    00_00_visit    0                                            113.252828
# 7783260382     10k    00_00_visit    0                                            140.815154
# 1178277844     10k    00_00_visit    0                                            131.586426
# 1622660825     10k    00_00_visit    0                                             94.915323
#
#                                                  blood_pressure_hand  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                          Left
# 5027574288     10k    00_00_visit    0                          Left
# 7783260382     10k    00_00_visit    0                          Left
# 1178277844     10k    00_00_visit    0                          Left
# 1622660825     10k    00_00_visit    0                          Left
#
#                                                   sitting_second_blood_pressure_diastolic  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                NaN
# 5027574288     10k    00_00_visit    0                                                NaN
# 7783260382     10k    00_00_visit    0                                                NaN
# 1178277844     10k    00_00_visit    0                                                NaN
# 1622660825     10k    00_00_visit    0                                          65.916086
#
#                                                   sitting_second_blood_pressure_pulse_rate  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                 NaN
# 5027574288     10k    00_00_visit    0                                                 NaN
# 7783260382     10k    00_00_visit    0                                                 NaN
# 1178277844     10k    00_00_visit    0                                                 NaN
# 1622660825     10k    00_00_visit    0                                                 NaN
#
#                                                   sitting_second_blood_pressure_systolic  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                               NaN
# 5027574288     10k    00_00_visit    0                                               NaN
# 7783260382     10k    00_00_visit    0                                               NaN
# 1178277844     10k    00_00_visit    0                                        121.511185
# 1622660825     10k    00_00_visit    0                                               NaN
#
#                                                  dizziness
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0               False
# 5027574288     10k    00_00_visit    0               False
# 7783260382     10k    00_00_visit    0               False
# 1178277844     10k    00_00_visit    0               False
# 1622660825     10k    00_00_visit    0               False

# %%
pl.fields
# Out:
# ['blood_pressure_hand',
#  'collection_date',
#  'collection_timestamp',
#  'dizziness',
#  'lying_blood_pressure_diastolic',
#  'lying_blood_pressure_pulse_rate',
#  'lying_blood_pressure_systolic',
#  'sitting_blood_pressure_diastolic',
#  'sitting_blood_pressure_pulse_rate',
#  'sitting_blood_pressure_systolic',
#  'sitting_second_blood_pressure_diastolic',
#  'sitting_second_blood_pressure_pulse_rate',
#  'sitting_second_blood_pressure_systolic',
#  'standing_one_min_blood_pressure_diastolic',
#  'standing_one_min_blood_pressure_pulse_rate',
#  'standing_one_min_blood_pressure_systolic',
#  'standing_three_min_blood_pressure_diastolic',
#  'standing_three_min_blood_pressure_pulse_rate',
#  'standing_three_min_blood_pressure_systolic',
#  'timezone',
#  'age',
#  'sex']

# %%
# filter out baseline visit
data = pl[pl.fields]  # get all fields, with age and sex
data = data[data.index.get_level_values('research_stage') == '00_00_visit']

# %% [markdown]
# # Bland Altman plot

# %%
from pheno_utils.blandaltman_plots import bland_altman_triple_plot

# %%
bland_altman_triple_plot(data, 'sitting_blood_pressure_systolic', 'lying_blood_pressure_systolic')

# %% [markdown]
# # Plot age-sex reference plots

# %%
# from pheno_utils.age_reference_plots import GenderAgeRefPlot

# %%
# gender_refplots = GenderAgeRefPlot(data = data, val_col = "lying_blood_pressure_diastolic", age_col = 'age')
# gender_refplots.plot()

# %% [markdown]
# # Dates plot

# %%
from pheno_utils.dates_plots import dates_dist_plot

# %%
dates_dist_plot(data, col="lying_blood_pressure_diastolic", date_col="collection_date")
