# %% [markdown]
# # Bone size, mineral and density (DXA) dataset
#
# ### Description
#
# Bone density was profiled based on DXA imaging, and includes measurements of mineral content in different parts of a variety of skeletal components.
#
# ### Introduction
#
# DXA (dual-energy x-ray absorptiometry) imaging is a method used to measure bone density and mineral content. A DXA scan uses a low dose of ionizing radiation to produce a detailed image of the body, specifically the bones. The scan is then analyzed by a software to determine the bone mineral density (BMD) and bone mineral content (BMC) in different parts of the body. This method is considered to be one of the most accurate methods for measuring bone density, as it is able to provide detailed information about the distribution of bone mineral content in different bony structures of the body skeleton. The spine and hip are most commonly measured because that is where most osteoporotic fractures occur. DXA imaging is commonly used for assessing the risk of osteoporosis, a condition characterized by low bone density and increased risk of fractures, and for monitoring the effects of treatments for the condition.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Dual-energy X-ray Absorptiometry (DXA) was performed with the GE Lunar Prodigy Advance device (GE Healthcare, USA) and the GE CoreScan and OneScan software applications. Before the scan, participants were asked to remove all metal items, heavy clothing and shoes. Bone mineral density was measured from the Femur necks, bilaterally and from the spine vertebra L1-L4. The Spine and femur imaging was performed with the OneScan, which performs an anterior posterior (AP) Spine and the dual femur exam without repositioning between scans. Participants were placed on the scanner bed with legs internally rotated and secured using a foot brace.
# The AP Spine measurement and analysis provides an estimate of bone mineral density for the lumbar spine while the Dual Femur measurement measures the density in the proximal femurs (femur neck). These values can then be compared to reference populations providing Z-scores that are matched for age, sex and ethnicity; and T-scores which indicate how many standard deviations a patient's value is from the mean value of a healthy Young Adult reference population (NHANES).
#
# ![DXA](data:image/jpeg;base64,...)
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `bone_density.parquet`
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/022-bone_density.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/22)

# %%
# %load_ext autoreload
# %autoreload 2

from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('bone_density', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for bone_density with
# 289 fields
# 2 tables: ['bone_density', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                       folder_id   feature_set  \
# tabular_field_name
# collection_date              22  bone_density
# timezone                     22  bone_density
# collection_timestamp         22  bone_density
# body_arm_left_area           22  bone_density
# body_arm_left_bmc            22  bone_density
# ...                         ...           ...
# spine_l4_bmc                 22  bone_density
# spine_l4_bmd                 22  bone_density
# spine_l4_t_score             22  bone_density
# spine_l4_ya_percent          22  bone_density
# spine_l4_z_score             22  bone_density
#
#                                             field_string  \
# tabular_field_name
# collection_date             Collection date (YYYY-MM-DD)
# timezone                                        Timezone
# collection_timestamp                Collection timestamp
# body_arm_left_area                    Body arm left area
# body_arm_left_bmc     Body arm left bone mineral content
# ...                                                  ...
# spine_l4_bmc               Spine l4 bone mineral content
# spine_l4_bmd               Spine l4 bone mineral density
# spine_l4_t_score                        Spine l4 t-score
# spine_l4_ya_percent         Spine l4 young-adult percent
# spine_l4_z_score                        Spine l4 z-score
#
#                                       description_string  \
# tabular_field_name
# collection_date             Collection date (YYYY-MM-DD)
# timezone                                        Timezone
# collection_timestamp                Collection timestamp
# body_arm_left_area                    Body left arm area
# body_arm_left_bmc     Body left arm bone mineral content
# ...                                                  ...
# spine_l4_bmc               Spine l4 bone mineral content
# spine_l4_bmd               Spine l4 bone mineral density
# spine_l4_t_score                        Spine l4 t-score
# spine_l4_ya_percent         Spine l4 young-adult percent
# spine_l4_z_score                        Spine l4 z-score
#
#                                       relative_location            field_type  \
# tabular_field_name
# collection_date       bone_density/bone_density.parquet                  Date
# timezone              bone_density/bone_density.parquet  Categorical (single)
# collection_timestamp  bone_density/bone_density.parquet                  Date
# body_arm_left_area    bone_density/bone_density.parquet            Continuous
# body_arm_left_bmc     bone_density/bone_density.parquet            Continuous
# ...                                                 ...                   ...
# spine_l4_bmc          bone_density/bone_density.parquet            Continuous
# spine_l4_bmd          bone_density/bone_density.parquet            Continuous
# spine_l4_t_score      bone_density/bone_density.parquet            Continuous
# spine_l4_ya_percent   bone_density/bone_density.parquet            Continuous
# spine_l4_z_score      bone_density/bone_density.parquet            Continuous
#
#                       bulk_dictionary  bulk_file_extension  data_coding  \
# tabular_field_name
# collection_date                   NaN                  NaN          NaN
# timezone                          NaN                  NaN          NaN
# collection_timestamp              NaN                  NaN          NaN
# body_arm_left_area                NaN                  NaN          NaN
# body_arm_left_bmc                 NaN                  NaN          NaN
# ...                               ...                  ...          ...
# spine_l4_bmc                      NaN                  NaN          NaN
# spine_l4_bmd                      NaN                  NaN          NaN
# spine_l4_t_score                  NaN                  NaN          NaN
# spine_l4_ya_percent               NaN                  NaN          NaN
# spine_l4_z_score                  NaN                  NaN          NaN
#
#                      stability      units  sampling_rate   strata       sexed  \
# tabular_field_name
# collection_date       Accruing       Time            NaN  Primary  Both sexes
# timezone                   NaN        NaN            NaN      NaN         NaN
# collection_timestamp  Accruing       Time            NaN  Primary  Both sexes
# body_arm_left_area    Accruing       cm^2            NaN  Primary  Both sexes
# body_arm_left_bmc     Accruing       gram            NaN  Primary  Both sexes
# ...                        ...        ...            ...      ...         ...
# spine_l4_bmc          Accruing       gram            NaN  Primary  Both sexes
# spine_l4_bmd          Accruing  gram/cm^2            NaN  Primary  Both sexes
# spine_l4_t_score      Accruing        NaN            NaN  Primary  Both sexes
# spine_l4_ya_percent   Accruing          %            NaN  Primary  Both sexes
# spine_l4_z_score      Accruing        NaN            NaN  Primary  Both sexes
#
#                        array  list_of_tags       debut  transformation  \
# tabular_field_name
# collection_date       Single           NaN  2020-06-09             NaN
# timezone                 NaN           NaN         NaN             NaN
# collection_timestamp  Single           NaN  2020-06-09             NaN
# body_arm_left_area    Single           NaN  2020-06-09             NaN
# body_arm_left_bmc     Single           NaN  2020-06-09             NaN
# ...                      ...           ...         ...             ...
# spine_l4_bmc          Single           NaN  2020-06-09             NaN
# spine_l4_bmd          Single           NaN  2020-06-09             NaN
# spine_l4_t_score      Single           NaN  2020-06-09             NaN
# spine_l4_ya_percent   Single           NaN  2020-06-09             NaN
# spine_l4_z_score      Single           NaN  2020-06-09             NaN
#
#                                         pandas_dtype  completed
# tabular_field_name
# collection_date                       datetime64[ns]        NaN
# timezone                                      string        NaN
# collection_timestamp  datetime64[ns, Asia/Jerusalem]        NaN
# body_arm_left_area                             float        NaN
# body_arm_left_bmc                              float        NaN
# ...                                              ...        ...
# spine_l4_bmc                                   float        NaN
# spine_l4_bmd                                   float        NaN
# spine_l4_t_score                               float        NaN
# spine_l4_ya_percent                            float        NaN
# spine_l4_z_score                               float        NaN
#
# [287 rows x 20 columns]

# %%
# Show all fields
pl[pl.fields]
# Out:
#                                                   body_arm_left_area  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                    154.557452
# 5027574288     10k    00_00_visit    0                    272.801177
# 7783260382     10k    00_00_visit    0                    135.963425
# 1178277844     10k    00_00_visit    0                    168.515409
# 1622660825     10k    00_00_visit    0                    167.543459
# ...                                                              ...
# 9642255339     10k    02_01_visit    0                    154.818905
# 9668685572     10k    02_01_visit    0                    163.833335
# 9704705313     10k    02_01_visit    0                    134.586102
# 9887688063     10k    01_01_visit    0                    192.374279
# 9992994539     10k    02_00_visit    0                    140.697647
#
#                                                   body_arm_left_bmc  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                   101.213893
# 5027574288     10k    00_00_visit    0                   137.169385
# 7783260382     10k    00_00_visit    0                   170.581260
# 1178277844     10k    00_00_visit    0                   131.075196
# 1622660825     10k    00_00_visit    0                   114.900034
# ...                                                             ...
# 9642255339     10k    02_01_visit    0                   110.199239
# 9668685572     10k    02_01_visit    0                   161.347210
# 9704705313     10k    02_01_visit    0                   143.934292
# 9887688063     10k    01_01_visit    0                   135.697336
# 9992994539     10k    02_00_visit    0                   205.943391
#
#                                                   body_arm_left_bmd  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                    -3.610433
# 5027574288     10k    00_00_visit    0                     1.554153
# 7783260382     10k    00_00_visit    0                     0.680769
# 1178277844     10k    00_00_visit    0                     1.554153
# 1622660825     10k    00_00_visit    0                    -1.028349
# ...                                                             ...
# 9642255339     10k    02_01_visit    0                    -0.239611
# 9668685572     10k    02_01_visit    0                    -1.060079
# 9704705313     10k    02_01_visit    0                     1.554153
# 9887688063     10k    01_01_visit    0                     1.554153
# 9992994539     10k    02_00_visit    0                    -1.950470
#
#                                                   body_arm_right_area  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                     207.315659
# 5027574288     10k    00_00_visit    0                     289.481556
# 7783260382     10k    00_00_visit    0                     275.135023
# 1178277844     10k    00_00_visit    0                     229.866526
# 1622660825     10k    00_00_visit    0                     109.357390
# ...                                                               ...
# 9642255339     10k    02_01_visit    0                     188.415611
# 9668685572     10k    02_01_visit    0                     254.813677
# 9704705313     10k    02_01_visit    0                      90.386314
# 9887688063     10k    01_01_visit    0                     145.109647
# 9992994539     10k    02_00_visit    0                     311.559040
#
#                                                   body_arm_right_bmc  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                    140.258994
# 5027574288     10k    00_00_visit    0                    277.563117
# 7783260382     10k    00_00_visit    0                    219.162117
# 1178277844     10k    00_00_visit    0                    263.731621
# 1622660825     10k    00_00_visit    0                     94.114823
# ...                                                              ...
# 9642255339     10k    02_01_visit    0                     64.174798
# 9668685572     10k    02_01_visit    0                    116.220397
# 9704705313     10k    02_01_visit    0                    112.336298
# 9887688063     10k    01_01_visit    0                    213.398638
# 9992994539     10k    02_00_visit    0                    184.844904
#
#                                                   body_arm_right_bmd  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                     -0.059369
# 5027574288     10k    00_00_visit    0                      1.554153
# 7783260382     10k    00_00_visit    0                     -0.882645
# 1178277844     10k    00_00_visit    0                      1.554153
# 1622660825     10k    00_00_visit    0                     -0.890750
# ...                                                              ...
# 9642255339     10k    02_01_visit    0                      0.010260
# 9668685572     10k    02_01_visit    0                     -0.741318
# 9704705313     10k    02_01_visit    0                      1.108905
# 9887688063     10k    01_01_visit    0                     -0.858091
# 9992994539     10k    02_00_visit    0                     -1.443984
#
#                                                   body_arms_area  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                317.589248
# 5027574288     10k    00_00_visit    0                426.269469
# 7783260382     10k    00_00_visit    0                290.293502
# 1178277844     10k    00_00_visit    0                403.788057
# 1622660825     10k    00_00_visit    0                230.313045
# ...                                                          ...
# 9642255339     10k    02_01_visit    0                287.935153
# 9668685572     10k    02_01_visit    0                537.810182
# 9704705313     10k    02_01_visit    0                288.584467
# 9887688063     10k    01_01_visit    0                277.716338
# 9992994539     10k    02_00_visit    0                519.071275
#
#                                                   body_arms_bmc  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0               134.084545
# 5027574288     10k    00_00_visit    0               518.632262
# 7783260382     10k    00_00_visit    0               306.772884
# 1178277844     10k    00_00_visit    0               502.505298
# 1622660825     10k    00_00_visit    0               192.361792
# ...                                                         ...
# 9642255339     10k    02_01_visit    0               231.229315
# 9668685572     10k    02_01_visit    0               494.299152
# 9704705313     10k    02_01_visit    0               276.814451
# 9887688063     10k    01_01_visit    0               254.289705
# 9992994539     10k    02_00_visit    0               408.148656
#
#                                                   body_arms_bmd  body_dose  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                 1.539903        0.4
# 5027574288     10k    00_00_visit    0                 1.554153        0.4
# 7783260382     10k    00_00_visit    0                 1.554153        0.4
# 1178277844     10k    00_00_visit    0                 1.554153        0.4
# 1622660825     10k    00_00_visit    0                 1.554153        0.4
# ...                                                         ...        ...
# 9642255339     10k    02_01_visit    0                 1.554153        0.4
# 9668685572     10k    02_01_visit    0                -0.271035        0.4
# 9704705313     10k    02_01_visit    0                 1.554153        0.4
# 9887688063     10k    01_01_visit    0                 1.554153        0.4
# 9992994539     10k    02_00_visit    0                -0.673833        0.4
#
#                                                   ...  \
# participant_id cohort research_stage array_index  ...
# 5516424321     10k    00_00_visit    0            ...
# 5027574288     10k    00_00_visit    0            ...
# 7783260382     10k    00_00_visit    0            ...
# 1178277844     10k    00_00_visit    0            ...
# 1622660825     10k    00_00_visit    0            ...
# ...                                               ...
# 9642255339     10k    02_01_visit    0            ...
# 9668685572     10k    02_01_visit    0            ...
# 9704705313     10k    02_01_visit    0            ...
# 9887688063     10k    01_01_visit    0            ...
# 9992994539     10k    02_00_visit    0            ...
#
#                                                   spine_l4_average_height  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                           3.225142
# 5027574288     10k    00_00_visit    0                           4.006343
# 7783260382     10k    00_00_visit    0                           4.249040
# 1178277844     10k    00_00_visit    0                           4.144118
# 1622660825     10k    00_00_visit    0                           3.652848
# ...                                                                   ...
# 9642255339     10k    02_01_visit    0                           3.342992
# 9668685572     10k    02_01_visit    0                           2.312989
# 9704705313     10k    02_01_visit    0                           3.712434
# 9887688063     10k    01_01_visit    0                           3.220013
# 9992994539     10k    02_00_visit    0                           3.858134
#
#                                                   spine_l4_average_width  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                          4.962508
# 5027574288     10k    00_00_visit    0                          4.622850
# 7783260382     10k    00_00_visit    0                          4.929068
# 1178277844     10k    00_00_visit    0                          4.682384
# 1622660825     10k    00_00_visit    0                          4.552018
# ...                                                                  ...
# 9642255339     10k    02_01_visit    0                          4.073236
# 9668685572     10k    02_01_visit    0                          3.872449
# 9704705313     10k    02_01_visit    0                          4.640188
# 9887688063     10k    01_01_visit    0                          4.518818
# 9992994539     10k    02_00_visit    0                          4.271092
#
#                                                   spine_l4_bmc  spine_l4_bmd  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0               15.805239      1.465532
# 5027574288     10k    00_00_visit    0               18.419483      1.098099
# 7783260382     10k    00_00_visit    0               19.972680      1.470386
# 1178277844     10k    00_00_visit    0               13.869291      1.186521
# 1622660825     10k    00_00_visit    0               11.114374      1.253674
# ...                                                        ...           ...
# 9642255339     10k    02_01_visit    0               10.408837      1.160332
# 9668685572     10k    02_01_visit    0                7.581808      1.298817
# 9704705313     10k    02_01_visit    0                6.850108      1.456295
# 9887688063     10k    01_01_visit    0               17.206216      0.854752
# 9992994539     10k    02_00_visit    0               14.819810      1.817073
#
#                                                   spine_l4_t_score  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                   -2.247577
# 5027574288     10k    00_00_visit    0                    1.593972
# 7783260382     10k    00_00_visit    0                    2.222163
# 1178277844     10k    00_00_visit    0                   -1.726285
# 1622660825     10k    00_00_visit    0                   -0.076962
# ...                                                            ...
# 9642255339     10k    02_01_visit    0                   -0.414514
# 9668685572     10k    02_01_visit    0                   -1.498995
# 9704705313     10k    02_01_visit    0                    2.018487
# 9887688063     10k    01_01_visit    0                   -1.663278
# 9992994539     10k    02_00_visit    0                   -0.456261
#
#                                                   spine_l4_ya_percent  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                      95.691147
# 5027574288     10k    00_00_visit    0                      92.527545
# 7783260382     10k    00_00_visit    0                      74.488114
# 1178277844     10k    00_00_visit    0                      74.868984
# 1622660825     10k    00_00_visit    0                      75.282447
# ...                                                               ...
# 9642255339     10k    02_01_visit    0                      78.462783
# 9668685572     10k    02_01_visit    0                      98.745253
# 9704705313     10k    02_01_visit    0                      97.733046
# 9887688063     10k    01_01_visit    0                      72.086639
# 9992994539     10k    02_00_visit    0                     114.717626
#
#                                                   spine_l4_z_score  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                    2.867866
# 5027574288     10k    00_00_visit    0                   -1.576274
# 7783260382     10k    00_00_visit    0                   -1.806000
# 1178277844     10k    00_00_visit    0                    1.202933
# 1622660825     10k    00_00_visit    0                   -0.736423
# ...                                                            ...
# 9642255339     10k    02_01_visit    0                   -3.093642
# 9668685572     10k    02_01_visit    0                   -0.917619
# 9704705313     10k    02_01_visit    0                    1.166705
# 9887688063     10k    01_01_visit    0                    1.010741
# 9992994539     10k    02_00_visit    0                   -0.473364
#
#                                                         timezone        age  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            asia/jerusalem  54.447672
# 5027574288     10k    00_00_visit    0            asia/jerusalem  54.169913
# 7783260382     10k    00_00_visit    0            asia/jerusalem  45.892093
# 1178277844     10k    00_00_visit    0            asia/jerusalem  44.435100
# 1622660825     10k    00_00_visit    0            asia/jerusalem  44.621536
# ...                                                          ...        ...
# 9642255339     10k    02_01_visit    0            asia/jerusalem  61.462461
# 9668685572     10k    02_01_visit    0            asia/jerusalem  55.199891
# 9704705313     10k    02_01_visit    0            asia/jerusalem  42.207211
# 9887688063     10k    01_01_visit    0            asia/jerusalem  57.157314
# 9992994539     10k    02_00_visit    0            asia/jerusalem  51.376179
#
#                                                      sex
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            Female
# 5027574288     10k    00_00_visit    0              Male
# 7783260382     10k    00_00_visit    0              Male
# 1178277844     10k    00_00_visit    0            Female
# 1622660825     10k    00_00_visit    0              Male
# ...                                                  ...
# 9642255339     10k    02_01_visit    0              Male
# 9668685572     10k    02_01_visit    0            Female
# 9704705313     10k    02_01_visit    0              Male
# 9887688063     10k    01_01_visit    0              Male
# 9992994539     10k    02_00_visit    0              Male
#
# [603 rows x 289 columns]

# %% [markdown]
# # Plot histogram

# %%
from pheno_utils.basic_plots import hist_ecdf_plots

# %%
# filter out baseline visit
# age & sex are added automatically by the loader
col = "body_arm_right_area"

df = pl[[col, "age", "sex", "collection_date"]].loc[:,:,"00_00_visit",:,:]

df.head()
# Out:
#                                    body_arm_right_area        age     sex  \
# participant_id cohort array_index
# 5516424321     10k    0                     207.315659  54.447672  Female
# 5027574288     10k    0                     289.481556  54.169913    Male
# 7783260382     10k    0                     275.135023  45.892093    Male
# 1178277844     10k    0                     229.866526  44.435100  Female
# 1622660825     10k    0                     109.357390  44.621536    Male
#
#                                                 collection_date
# participant_id cohort array_index
# 5516424321     10k    0           2022-01-16 02:40:27.280033536
# 5027574288     10k    0           2021-10-14 18:49:52.871606528
# 7783260382     10k    0           2021-06-17 06:55:28.823643648
# 1178277844     10k    0           2021-07-26 10:02:07.192320768
# 1622660825     10k    0           2022-05-19 16:16:26.799786240

# %%
# plot histogram and ecdf
hist_ecdf_plots(df.dropna(subset=[col,"sex", "age"]), col, gender_col="sex")

# stats
display(df[col].describe().to_frame().T)
# Out:
#                      count        mean        std         min         25%  \
# body_arm_right_area  497.0  171.332504  84.256019 -851.808271  145.109647
#
#                             50%         75%         max
# body_arm_right_area  173.682803  204.702379  331.281317

# %% [markdown]
# # Plot age-sex reference plots

# %%
from pheno_utils.age_reference_plots import GenderAgeRefPlot

# %%
gender_refplots = GenderAgeRefPlot(df.dropna(subset=[col, "sex", "age"]), "body_arm_right_area", age_col="age")
gender_refplots.plot()
