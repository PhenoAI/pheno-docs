# %% [markdown]
# # Psychological and social health
#
# ### Description
#
# Coming soon
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes information about psychological and social health factors, captured through two lifestyle surveys.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `psychological_and_social_health`
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/057-psychological_and_social_health.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/57)

# %%
# %load_ext autoreload
# %autoreload 2
from pheno_utils import PhenoLoader
import random

# %%
pl = PhenoLoader('psychological_and_social_health', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for psychological_and_social_health with
# 46 fields
# 2 tables: ['psychological_and_social_health', 'age_sex']

# %% [markdown]
# ## Data dictionary

# %%
pl.dict.head()
# Out:
#                                              folder_id  \
# tabular_field_name
# activity_social_visit_frequency                     57
# activity_social_weekly                              57
# health_mental_current_mood_swings_frequency         57
# health_mental_current_miserable                     57
# health_mental_current_irritable                     57
#
#                                                                  feature_set  \
# tabular_field_name
# activity_social_visit_frequency              psychological_and_social_health
# activity_social_weekly                       psychological_and_social_health
# health_mental_current_mood_swings_frequency  psychological_and_social_health
# health_mental_current_miserable              psychological_and_social_health
# health_mental_current_irritable              psychological_and_social_health
#
#                                                                   field_string  \
# tabular_field_name
# activity_social_visit_frequency              Frequency of friend/family visits
# activity_social_weekly                               Leisure/social activities
# health_mental_current_mood_swings_frequency                        Mood swings
# health_mental_current_miserable                                  Miserableness
# health_mental_current_irritable                                   Irritability
#
#                                                                              relative_location  \
# tabular_field_name
# activity_social_visit_frequency              psychological_and_social_health/psychological_...
# activity_social_weekly                       psychological_and_social_health/psychological_...
# health_mental_current_mood_swings_frequency  psychological_and_social_health/psychological_...
# health_mental_current_miserable              psychological_and_social_health/psychological_...
# health_mental_current_irritable              psychological_and_social_health/psychological_...
#
#                                              bulk_file_extension  \
# tabular_field_name
# activity_social_visit_frequency                              NaN
# activity_social_weekly                                       NaN
# health_mental_current_mood_swings_frequency                  NaN
# health_mental_current_miserable                              NaN
# health_mental_current_irritable                              NaN
#
#                                              bulk_dictionary  \
# tabular_field_name
# activity_social_visit_frequency                          NaN
# activity_social_weekly                                   NaN
# health_mental_current_mood_swings_frequency              NaN
# health_mental_current_miserable                          NaN
# health_mental_current_irritable                          NaN
#
#                                                                             description_string  \
# tabular_field_name
# activity_social_visit_frequency              How often do you visit friends or family or ha...
# activity_social_weekly                       Which of the following do you attend once a we...
# health_mental_current_mood_swings_frequency               Does your mood often go up and down?
# health_mental_current_miserable               Do you ever feel 'just miserable' for no reason?
# health_mental_current_irritable                                   Are you an irritable person?
#
#                                                          field_type     array  \
# tabular_field_name
# activity_social_visit_frequency                Categorical (single)    Single
# activity_social_weekly                       Categorical (multiple)  Multiple
# health_mental_current_mood_swings_frequency    Categorical (single)    Single
# health_mental_current_miserable                Categorical (single)    Single
# health_mental_current_irritable                Categorical (single)    Single
#
#                                             pandas_dtype stability  units  \
# tabular_field_name
# activity_social_visit_frequency                      int  Accruing    NaN
# activity_social_weekly                            object  Accruing    NaN
# health_mental_current_mood_swings_frequency          int  Accruing    NaN
# health_mental_current_miserable                      int  Accruing    NaN
# health_mental_current_irritable                      int  Accruing    NaN
#
#                                              sampling_rate   strata  \
# tabular_field_name
# activity_social_visit_frequency                        NaN  Primary
# activity_social_weekly                                 NaN  Primary
# health_mental_current_mood_swings_frequency            NaN  Primary
# health_mental_current_miserable                        NaN  Primary
# health_mental_current_irritable                        NaN  Primary
#
#                                                   sexed     debut  completed  \
# tabular_field_name
# activity_social_visit_frequency              Both sexes  1/9/2019        NaN
# activity_social_weekly                       Both sexes  1/9/2019        NaN
# health_mental_current_mood_swings_frequency  Both sexes  1/9/2019        NaN
# health_mental_current_miserable              Both sexes  1/9/2019        NaN
# health_mental_current_irritable              Both sexes  1/9/2019        NaN
#
#                                             data_coding
# tabular_field_name
# activity_social_visit_frequency                  100327
# activity_social_weekly                           100328
# health_mental_current_mood_swings_frequency      100349
# health_mental_current_miserable                  100349
# health_mental_current_irritable                  100349

# %%
pl.dfs['psychological_and_social_health'].head()
# Out:
#                                                  activity_social_visit_frequency  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                         About once a week
# 5027574288     10k    00_00_visit    0                        About once a month
# 7783260382     10k    00_00_visit    0                        About once a month
# 1178277844     10k    00_00_visit    0                          2-4 times a week
# 1622660825     10k    00_00_visit    0                        About once a month
#
#                                                                       activity_social_weekly  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0               [Sports club or gym, None of the above]
# 5027574288     10k    00_00_visit    0            [Sports club or gym, Other group activity]
# 7783260382     10k    00_00_visit    0                                   [None of the above]
# 1178277844     10k    00_00_visit    0              [Religious group, Adult education class]
# 1622660825     10k    00_00_visit    0                               [Adult education class]
#
#                                                  health_mental_current_mood_swings_frequency  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                    No
# 5027574288     10k    00_00_visit    0                                                   Yes
# 7783260382     10k    00_00_visit    0                                                   Yes
# 1178277844     10k    00_00_visit    0                                                    No
# 1622660825     10k    00_00_visit    0                                                   Yes
#
#                                                  health_mental_current_miserable  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                        No
# 5027574288     10k    00_00_visit    0                                       Yes
# 7783260382     10k    00_00_visit    0                                       Yes
# 1178277844     10k    00_00_visit    0                                        No
# 1622660825     10k    00_00_visit    0                                       Yes
#
#                                                  health_mental_current_irritable  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                        No
# 5027574288     10k    00_00_visit    0                                        No
# 7783260382     10k    00_00_visit    0                                       Yes
# 1178277844     10k    00_00_visit    0                                        No
# 1622660825     10k    00_00_visit    0                                       Yes
#
#                                                  health_mental_current_sensitive  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                       Yes
# 5027574288     10k    00_00_visit    0                                        No
# 7783260382     10k    00_00_visit    0                                       Yes
# 1178277844     10k    00_00_visit    0                                        No
# 1622660825     10k    00_00_visit    0                                        No
#
#                                                  health_mental_current_fed_up  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                    Yes
# 5027574288     10k    00_00_visit    0                                    Yes
# 7783260382     10k    00_00_visit    0                                    Yes
# 1178277844     10k    00_00_visit    0                                     No
# 1622660825     10k    00_00_visit    0                                    Yes
#
#                                                  health_mental_current_nervous  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                      No
# 5027574288     10k    00_00_visit    0                                      No
# 7783260382     10k    00_00_visit    0                                     Yes
# 1178277844     10k    00_00_visit    0                             Do not know
# 1622660825     10k    00_00_visit    0                                     Yes
#
#                                                  health_mental_current_worrier  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                     Yes
# 5027574288     10k    00_00_visit    0                                      No
# 7783260382     10k    00_00_visit    0                                     Yes
# 1178277844     10k    00_00_visit    0                                     Yes
# 1622660825     10k    00_00_visit    0                                     Yes
#
#                                                  health_mental_current_tense  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                   Yes
# 5027574288     10k    00_00_visit    0                                    No
# 7783260382     10k    00_00_visit    0                                   Yes
# 1178277844     10k    00_00_visit    0                                    No
# 1622660825     10k    00_00_visit    0                                   Yes
#
#                                                   ...  \
# participant_id cohort research_stage array_index  ...
# 5516424321     10k    00_00_visit    0            ...
# 5027574288     10k    00_00_visit    0            ...
# 7783260382     10k    00_00_visit    0            ...
# 1178277844     10k    00_00_visit    0            ...
# 1622660825     10k    00_00_visit    0            ...
#
#                                                  health_mental_past_irritable_two_days  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                     Do not know
# 5027574288     10k    00_00_visit    0                                             Yes
# 7783260382     10k    00_00_visit    0                                              No
# 1178277844     10k    00_00_visit    0                                     Do not know
# 1622660825     10k    00_00_visit    0                                             Yes
#
#                                                  health_mental_past_manic_symptoms  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                         NaN
# 5027574288     10k    00_00_visit    0                                         NaN
# 7783260382     10k    00_00_visit    0                                         NaN
# 1178277844     10k    00_00_visit    0                           None of the above
# 1622660825     10k    00_00_visit    0                                         NaN
#
#                                                  health_mental_past_manic_irritable_longest  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0              At least two days, but less than a week
# 5027574288     10k    00_00_visit    0                                                  NaN
# 7783260382     10k    00_00_visit    0              At least two days, but less than a week
# 1178277844     10k    00_00_visit    0                                       A week or more
# 1622660825     10k    00_00_visit    0                                       A week or more
#
#                                                  health_mental_past_manic_irritable_problems  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                   NaN
# 5027574288     10k    00_00_visit    0                                                   NaN
# 7783260382     10k    00_00_visit    0                                                   NaN
# 1178277844     10k    00_00_visit    0                                                   NaN
# 1622660825     10k    00_00_visit    0                                                   NaN
#
#                                                  health_mental_current_able_to_confide  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                               About once a week
# 5027574288     10k    00_00_visit    0                                    Almost daily
# 7783260382     10k    00_00_visit    0                           Never or almost never
# 1178277844     10k    00_00_visit    0                           Never or almost never
# 1622660825     10k    00_00_visit    0                               About once a week
#
#                                                                  health_mental_past_two_years_event  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            [Serious illness, injury or assault of a close...
# 5027574288     10k    00_00_visit    0                                          [None of the above]
# 7783260382     10k    00_00_visit    0                                     [Financial difficulties]
# 1178277844     10k    00_00_visit    0                                 [Marital separation/divorce]
# 1622660825     10k    00_00_visit    0                                          [None of the above]
#
#                                                           collection_timestamp  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0           2022-11-05 00:26:58.116574464
# 5027574288     10k    00_00_visit    0           2020-02-07 04:11:50.776566784
# 7783260382     10k    00_00_visit    0           2022-12-28 08:00:06.452548096
# 1178277844     10k    00_00_visit    0           2023-03-03 06:20:48.832640000
# 1622660825     10k    00_00_visit    0           2021-12-07 07:01:14.933780480
#
#                                                                collection_date  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0           2022-10-17 16:01:20.824883712
# 5027574288     10k    00_00_visit    0           2020-03-23 19:28:19.985250304
# 7783260382     10k    00_00_visit    0           2023-01-09 12:38:24.150213376
# 1178277844     10k    00_00_visit    0           2023-02-09 05:22:46.969990656
# 1622660825     10k    00_00_visit    0           2022-01-20 16:56:12.083890688
#
#                                                         timezone  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            asia/jerusalem
# 5027574288     10k    00_00_visit    0            asia/jerusalem
# 7783260382     10k    00_00_visit    0            asia/jerusalem
# 1178277844     10k    00_00_visit    0            asia/jerusalem
# 1622660825     10k    00_00_visit    0            asia/jerusalem
#
#                                                             data_source
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            follow_up_ukbb_survey
# 5027574288     10k    00_00_visit    0              initial_ukbb_survey
# 7783260382     10k    00_00_visit    0              initial_ukbb_survey
# 1178277844     10k    00_00_visit    0              initial_ukbb_survey
# 1622660825     10k    00_00_visit    0            follow_up_ukbb_survey
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Data coding
# A data-coding is a mapping between the actual data and the values used to represent it within the database for categorical features.

# %%
df_codes = pl.data_codings
df_codes.head()
# Out:
#   code_number  coding                                            english  \
# 0      001_03       0                                     asia/jerusalem
# 1      062_02       1                                             BRCA-1
# 2      062_02       2                                             BRCA-2
# 3      062_02      -1                                        Do not know
# 4      062_03       1  A relative of mine got breast, ovarian, or pro...
#
#                                               hebrew  answer_field_name  \
# 0                                          זמן ישראל                NaN
# 1                                             BRCA-1        brca_type_1
# 2                                             BRCA-2        brca_type_2
# 3                                          לא יודע/ת        brca_type_3
# 4  קרוב/ת משפחה חלה/תה בסרטן השד, השחלה, או הערמו...  brca_indication_1
#
#         sexed ukbb_compatible  ukbb_similar_coding scripting_instruction  \
# 0         NaN           False                  NaN                   NaN
# 1  Both sexes             NaN                  NaN                   NaN
# 2  Both sexes             NaN                  NaN                   NaN
# 3  Both sexes             NaN                  NaN                  NMUL
# 4  Both sexes             NaN                  NaN                   NaN
#
#   description notes
# 0    Timezone   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN

# %% [markdown]
# Each column represents a single question. Answers are saved as numbers.
# The type of the question (integer, or category with single/multiple choice) can be found in the data dictionary.

# %%
pl.dict['field_type'].value_counts()
# Out:
# field_type
# Categorical (single)      35
# Integer                    4
# Categorical (multiple)     2
# Datetime                   1
# Date                       1
# Text                       1
# Name: count, dtype: int64

# %% [markdown]
# ### Numeric questions

# %% [markdown]
# For numeric questions the answers are the numbers entered when filling the survey

# %%
pl.dict[pl.dict['field_type'] == 'Integer'].head()
# Out:
#                                                 folder_id  \
# tabular_field_name
# health_mental_past_depression_longest                  57
# health_mental_past_depression_episodes_number          57
# health_mental_past_disinterest_longest                 57
# health_mental_past_disinterest_episodes_number         57
#
#                                                                     feature_set  \
# tabular_field_name
# health_mental_past_depression_longest           psychological_and_social_health
# health_mental_past_depression_episodes_number   psychological_and_social_health
# health_mental_past_disinterest_longest          psychological_and_social_health
# health_mental_past_disinterest_episodes_number  psychological_and_social_health
#
#                                                                                    field_string  \
# tabular_field_name
# health_mental_past_depression_longest                              Longest period of depression
# health_mental_past_depression_episodes_number                     Number of depression episodes
# health_mental_past_disinterest_longest             Longest period of unenthusiasm / disinterest
# health_mental_past_disinterest_episodes_number  Number of unenthusiastic/disinterested episodes
#
#                                                                                 relative_location  \
# tabular_field_name
# health_mental_past_depression_longest           psychological_and_social_health/psychological_...
# health_mental_past_depression_episodes_number   psychological_and_social_health/psychological_...
# health_mental_past_disinterest_longest          psychological_and_social_health/psychological_...
# health_mental_past_disinterest_episodes_number  psychological_and_social_health/psychological_...
#
#                                                 bulk_file_extension  \
# tabular_field_name
# health_mental_past_depression_longest                           NaN
# health_mental_past_depression_episodes_number                   NaN
# health_mental_past_disinterest_longest                          NaN
# health_mental_past_disinterest_episodes_number                  NaN
#
#                                                 bulk_dictionary  \
# tabular_field_name
# health_mental_past_depression_longest                       NaN
# health_mental_past_depression_episodes_number               NaN
# health_mental_past_disinterest_longest                      NaN
# health_mental_past_disinterest_episodes_number              NaN
#
#                                                                                description_string  \
# tabular_field_name
# health_mental_past_depression_longest           How many weeks was the longest period when you...
# health_mental_past_depression_episodes_number   How many periods have you had when you were fe...
# health_mental_past_disinterest_longest          How many weeks was the longest period when you...
# health_mental_past_disinterest_episodes_number  How many periods have you had when you were un...
#
#                                                field_type   array  \
# tabular_field_name
# health_mental_past_depression_longest             Integer  Single
# health_mental_past_depression_episodes_number     Integer  Single
# health_mental_past_disinterest_longest            Integer  Single
# health_mental_past_disinterest_episodes_number    Integer  Single
#
#                                                pandas_dtype stability  units  \
# tabular_field_name
# health_mental_past_depression_longest                   int  Accruing    NaN
# health_mental_past_depression_episodes_number           int  Accruing    NaN
# health_mental_past_disinterest_longest                  int  Accruing    NaN
# health_mental_past_disinterest_episodes_number          int  Accruing    NaN
#
#                                                 sampling_rate   strata  \
# tabular_field_name
# health_mental_past_depression_longest                     NaN  Primary
# health_mental_past_depression_episodes_number             NaN  Primary
# health_mental_past_disinterest_longest                    NaN  Primary
# health_mental_past_disinterest_episodes_number            NaN  Primary
#
#                                                      sexed     debut  \
# tabular_field_name
# health_mental_past_depression_longest           Both sexes  1/9/2019
# health_mental_past_depression_episodes_number   Both sexes  1/9/2019
# health_mental_past_disinterest_longest          Both sexes  1/9/2019
# health_mental_past_disinterest_episodes_number  Both sexes  1/9/2019
#
#                                                 completed data_coding
# tabular_field_name
# health_mental_past_depression_longest                 NaN         NaN
# health_mental_past_depression_episodes_number         NaN         NaN
# health_mental_past_disinterest_longest                NaN         NaN
# health_mental_past_disinterest_episodes_number        NaN         NaN

# %%
# filter out baseline visit
col = 'health_mental_past_depression_episodes_number'

df = pl[[col, 'age', 'sex', 'collection_date']].loc[:,:,"00_00_visit",:,:]

df.head()
# Out:
#                                    health_mental_past_depression_episodes_number  \
# participant_id cohort array_index
# 5516424321     10k    0                                                        0
# 5027574288     10k    0                                                        0
# 7783260382     10k    0                                                        0
# 1178277844     10k    0                                                        0
# 1622660825     10k    0                                                        0
#
#                                          age     sex  \
# participant_id cohort array_index
# 5516424321     10k    0            54.447672  Female
# 5027574288     10k    0            54.169913    Male
# 7783260382     10k    0            45.892093    Male
# 1178277844     10k    0            44.435100  Female
# 1622660825     10k    0            44.621536    Male
#
#                                                 collection_date
# participant_id cohort array_index
# 5516424321     10k    0           2022-10-17 16:01:20.824883712
# 5027574288     10k    0           2020-03-23 19:28:19.985250304
# 7783260382     10k    0           2023-01-09 12:38:24.150213376
# 1178277844     10k    0           2023-02-09 05:22:46.969990656
# 1622660825     10k    0           2022-01-20 16:56:12.083890688

# %% [markdown]
# ### Categorical single choice questions

# %% [markdown]
#  For categorical qustions, answers are coded according to the data coding. The automatic setting for PhenoLoader shows the values in english.

# %%
single = pl.dict[pl.dict['field_type'] == 'Categorical (single)'].index.values.tolist()
# Select a random numeric question
single_question = random.choice(single)

pl[single_question][single_question].value_counts()
# Out:
# health_mental_past_manic_irritable_problems
# No problems                                                                                                 34
# Do not know                                                                                                  3
# Needed treatment or caused problems with work, relationships, finances, the law or other aspects of life     2
# Name: count, dtype: int64

# %% [markdown]
# To view the data codings you can set the preferred_language to 'coding' in PhenoLoader function.

# %%
pl = PhenoLoader('psychological_and_social_health', preferred_language='coding', base_path='s3://pheno-synthetic-data/data')

# %% [markdown]
# To change the representation of the answers, we can use the function tranform_answers from pheno_utils.questionnaires_handler or adjsut the parameter of preferred_language in the PhenoLoader function (default is english)

# %%
from pheno_utils.questionnaires_handler import transform_answers

# %% [markdown]
# Transorm to English

# %%
tranformed_english = transform_answers(single_question, pl[single_question][single_question], transform_from='Coding', transform_to='English', dict_df=pl.dict, mapping_df=df_codes)
print(single_question, pl.dict.loc[single_question]['data_coding'])
tranformed_english.value_counts()
# Out:
# health_mental_past_manic_irritable_problems 100500
# health_mental_past_manic_irritable_problems
# No problems                                                                                                 34
# Do not know                                                                                                  3
# Needed treatment or caused problems with work, relationships, finances, the law or other aspects of life     2
# Name: count, dtype: int64

# %% [markdown]
# ### Categorical multiple choice questions

# %% [markdown]
# Catrgorical multiple choice questions are coded in the same way as categorical single questions, but if multiple answers were chosen these are saved in different array_index rows of the same participant.

# %%
multiple = pl.dict[pl.dict['field_type'] == 'Categorical (multiple)'].index.values.tolist()
multiple_question = 'health_mental_past_two_years_event'

# %%
tranformed_english = transform_answers(multiple_question, pl[multiple_question][multiple_question], transform_from='coding', transform_to='english', 
                                     dict_df=pl.dict, mapping_df=pl.data_codings)

# %%
tranformed_english
# Out:
# participant_id  cohort  research_stage  array_index
# 5516424321      10k     00_00_visit     0              [Serious illness, injury or assault of a close...
# 5027574288      10k     00_00_visit     0                                            [None of the above]
# 7783260382      10k     00_00_visit     0                                       [Financial difficulties]
# 1178277844      10k     00_00_visit     0                                   [Marital separation/divorce]
# 1622660825      10k     00_00_visit     0                                            [None of the above]
#                                                                              ...
# 9642255339      10k     02_01_visit     0                                       [Financial difficulties]
# 9668685572      10k     02_01_visit     0                                            [None of the above]
# 9704705313      10k     02_01_visit     0                                       [Financial difficulties]
# 9887688063      10k     01_01_visit     0                                            [None of the above]
# 9992994539      10k     02_00_visit     0                                   [Marital separation/divorce]
# Name: health_mental_past_two_years_event, Length: 603, dtype: object

# %%
from collections import Counter
# Flatten the list of lists into a single list
flattened = [item for sublist in tranformed_english.dropna() for item in sublist]

# Count the frequency of each answer
answer_counts = Counter(flattened)

# Display the counts
print(answer_counts)
# Out:
# Counter({'Marital separation/divorce': 214, 'None of the above': 197, 'Serious illness, injury or assault of a close relative': 121, 'Financial difficulties': 76, 'Death of a spouse or partner': 75, 'Death of a close relative': 66, 'Prefer not to answer': 34, 'Serious illness, injury or assault to yourself': 21})
