# %% [markdown]
# # Population characteristics dataset
#
# ### Description
#
# Population characteristics of the Human Phenotype Project study participants.
#
# ### Introduction
#
# Population characteristics of the Human Phenotype Project include basic information about the participants regarding sex, living area, visits to the clinical testing center, and communication status.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Upon registration to the Human Phenotype Project, people are assigned with a registration code, which is their ID in the study and provide a telephone number and email by which all communications are conducted. Participants are asked about their date of birth and their sex, and are asked to schedule a visit to the assessment center.
#
# Personal and communication data is saved separately in a secure environment from the population characteristics information, which is saved with the participant designated ID.
#
# ### Data availability
#  <!-- for the example notebooks -->
# * population.parquet - contains sex, month and year of birth per participant
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/000-population.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/1)

# %%
# %load_ext autoreload
# %autoreload 2

from pheno_utils import PhenoLoader
# Out:
# /home/ec2-user/miniconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pl = PhenoLoader('population', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for population with
# 4 fields
# 1 tables: ['population']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                       field_string    description_string customer_field  \
# tabular_field_name
# month_of_birth      Month of birth        Month of birth          ready
# year_of_birth        Year of birth         Year of birth          ready
# sex                            Sex                   Sex          ready
# study_id                  Study ID  The study identifier          ready
#
#                     folder_id feature_set            field_type     strata  \
# tabular_field_name
# month_of_birth              1  population  Categorical (single)    Primary
# year_of_birth               1  population               Integer    Primary
# sex                         1  population  Categorical (single)    Primary
# study_id                    1  population  Categorical (single)  Auxiliary
#
#                    data_coding   array pandas_dtype  ...  ukbb_compatible  \
# tabular_field_name                                   ...
# month_of_birth          042_03  Single     category  ...             True
# year_of_birth              NaN  Single          int  ...             True
# sex                          9  Single     category  ...             True
# study_id                000_01  Single     category  ...            False
#
#                    ukbb_field_id  list_of_tags stability       sexed  \
# tabular_field_name
# month_of_birth              52.0           NaN  Accruing  Both sexes
# year_of_birth               34.0           NaN  Accruing  Both sexes
# sex                         31.0           NaN  Accruing  Both sexes
# study_id                     NaN           NaN  Accruing  Both sexes
#
#                          debut  completed  browser_image_label  \
# tabular_field_name
# month_of_birth      2019-01-01        NaN                  NaN
# year_of_birth       2019-01-01        NaN                  NaN
# sex                 2019-01-01        NaN                  NaN
# study_id            2019-01-01        NaN                  NaN
#
#                     browser_image_caption  browser_image_fname
# tabular_field_name
# month_of_birth                        NaN                  NaN
# year_of_birth                         NaN                  NaN
# sex                                   NaN                  NaN
# study_id                              NaN                  NaN
#
# [4 rows x 35 columns]

# %%
# Show all fields
pl[pl.fields]
# Out:
#                       month_of_birth     sex study_id  year_of_birth
# participant_id cohort
# 1704566168     10k          February    Male      10k           1968
# 9564032783     10k             March    Male      10k           1969
# 9835639191     10k           January  Female      10k           1977
# 2183955933     10k             March    Male      10k           1968
# 3895522130     10k          December  Female      10k           1976
# ...                              ...     ...      ...            ...
# 5989472762     10k          November    Male      10k           1955
# 6188803594     10k               May  Female      10k           1977
# 3444610916     10k             April    Male      10k           1976
# 1721658019     10k          December    Male      10k           1972
# 4516787031     10k             March    Male      10k           1976
#
# [1700 rows x 4 columns]
