# %% [markdown]
# # Family history
#
# ### Description
#
# Family history information in medical research involves collecting data on genetic and hereditary conditions passed down through generations. This includes predispositions to diseases such as cancer, cardiovascular conditions, diabetes, and mental health disorders, helping identify potential health risks based on familial patterns.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes information about a participant's family history, captured through two lifestyle surveys and the Initial Medical Survey.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 2 parquet files:  `initial_medical.parquet` and `ukbb.parquet`. The ukbb.parquet contains questions asked in our lifestyle surveys at the baseline and follow up stages.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/052-family_history.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/52)

# %%
# %load_ext autoreload
# %autoreload 2

from pheno_utils import PhenoLoader
import pandas as pd
import random

# %%
pl = PhenoLoader('family_history', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for family_history with
# 57 fields
# 3 tables: ['initial_medical', 'ukbb', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict.head()
# Out:
#                                folder_id      feature_set  \
# tabular_field_name
# sudden_death_family                   52  initial_medical
# family_history                        52  initial_medical
# hypertension_family_number            52  initial_medical
# hyperlipidemia_family_number          52  initial_medical
# type_1_diabetes_family_number         52  initial_medical
#
#                                                 field_string  \
# tabular_field_name
# sudden_death_family                      Sudden death family
# family_history                                Family history
# hypertension_family_number        Hypertension family number
# hyperlipidemia_family_number    Hyperlipidemia family number
# type_1_diabetes_family_number  Type 1 diabetes family number
#
#                                                     relative_location  \
# tabular_field_name
# sudden_death_family            family_history/initial_medical.parquet
# family_history                 family_history/initial_medical.parquet
# hypertension_family_number     family_history/initial_medical.parquet
# hyperlipidemia_family_number   family_history/initial_medical.parquet
# type_1_diabetes_family_number  family_history/initial_medical.parquet
#
#                                bulk_file_extension  bulk_dictionary  \
# tabular_field_name
# sudden_death_family                            NaN              NaN
# family_history                                 NaN              NaN
# hypertension_family_number                     NaN              NaN
# hyperlipidemia_family_number                   NaN              NaN
# type_1_diabetes_family_number                  NaN              NaN
#
#                                                               description_string  \
# tabular_field_name
# sudden_death_family            Has one or more of your close family members d...
# family_history                 Has one or more of your close family members s...
# hypertension_family_number     How many of your close family members have hig...
# hyperlipidemia_family_number   How many of your close family members have ele...
# type_1_diabetes_family_number  How many of your close family members have typ...
#
#                                            field_type     array pandas_dtype  \
# tabular_field_name
# sudden_death_family              Categorical (single)    Single          int
# family_history                 Categorical (multiple)  Multiple       object
# hypertension_family_number                    Integer    Single          int
# hyperlipidemia_family_number                  Integer    Single          int
# type_1_diabetes_family_number                 Integer    Single          int
#
#                               stability units  sampling_rate   strata  \
# tabular_field_name
# sudden_death_family            Accruing   NaN            NaN  Primary
# family_history                 Accruing   NaN            NaN  Primary
# hypertension_family_number     Accruing   NaN            NaN  Primary
# hyperlipidemia_family_number   Accruing   NaN            NaN  Primary
# type_1_diabetes_family_number  Accruing   NaN            NaN  Primary
#
#                                     sexed      debut  completed data_coding
# tabular_field_name
# sudden_death_family            Both sexes  2/26/2020        NaN          21
# family_history                 Both sexes  2/26/2020        NaN      052_01
# hypertension_family_number     Both sexes  2/26/2020        NaN         NaN
# hyperlipidemia_family_number   Both sexes  2/26/2020        NaN         NaN
# type_1_diabetes_family_number  Both sexes  2/26/2020        NaN         NaN

# %%
pl.dfs['ukbb'].head()
# Out:
#                                                  early_life_breastfeeding  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                NaN
# 5027574288     10k    00_00_visit    0                                NaN
# 7783260382     10k    00_00_visit    0                                 No
# 1178277844     10k    00_00_visit    0                                NaN
# 1622660825     10k    00_00_visit    0                        Do not know
#
#                                                  early_life_comparative_body_weight  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                          NaN
# 5027574288     10k    00_00_visit    0                                          NaN
# 7783260382     10k    00_00_visit    0                                      Thinner
# 1178277844     10k    00_00_visit    0                                          NaN
# 1622660825     10k    00_00_visit    0                                About average
#
#                                                  early_life_comparative_body_height  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                          NaN
# 5027574288     10k    00_00_visit    0                                          NaN
# 7783260382     10k    00_00_visit    0                                      Shorter
# 1178277844     10k    00_00_visit    0                                          NaN
# 1622660825     10k    00_00_visit    0                                About average
#
#                                                  early_life_handedness  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                             NaN
# 5027574288     10k    00_00_visit    0                             NaN
# 7783260382     10k    00_00_visit    0                    Right-handed
# 1178277844     10k    00_00_visit    0                    Right-handed
# 1622660825     10k    00_00_visit    0                    Right-handed
#
#                                                  early_life_adopted  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                          NaN
# 5027574288     10k    00_00_visit    0                          NaN
# 7783260382     10k    00_00_visit    0                           No
# 1178277844     10k    00_00_visit    0                          NaN
# 1622660825     10k    00_00_visit    0                           No
#
#                                                  early_life_multiple_birth  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                 NaN
# 5027574288     10k    00_00_visit    0                                 NaN
# 7783260382     10k    00_00_visit    0                                  No
# 1178277844     10k    00_00_visit    0                                 NaN
# 1622660825     10k    00_00_visit    0                                  No
#
#                                                  early_life_mother_smoking  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                 NaN
# 5027574288     10k    00_00_visit    0                                 NaN
# 7783260382     10k    00_00_visit    0                                  No
# 1178277844     10k    00_00_visit    0                                  No
# 1622660825     10k    00_00_visit    0                                  No
#
#                                                  family_history_father_alive  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                    No
# 5027574288     10k    00_00_visit    0                                   NaN
# 7783260382     10k    00_00_visit    0                                    No
# 1178277844     10k    00_00_visit    0                                    No
# 1622660825     10k    00_00_visit    0                                   Yes
#
#                                                  family_history_adopted_father_alive  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                           NaN
# 5027574288     10k    00_00_visit    0                                           NaN
# 7783260382     10k    00_00_visit    0                                           NaN
# 1178277844     10k    00_00_visit    0                                           NaN
# 1622660825     10k    00_00_visit    0                                           NaN
#
#                                                   family_history_current_father_age  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                            0
# 5027574288     10k    00_00_visit    0                                            0
# 7783260382     10k    00_00_visit    0                                            0
# 1178277844     10k    00_00_visit    0                                            0
# 1622660825     10k    00_00_visit    0                                           72
#
#                                                   ...  \
# participant_id cohort research_stage array_index  ...
# 5516424321     10k    00_00_visit    0            ...
# 5027574288     10k    00_00_visit    0            ...
# 7783260382     10k    00_00_visit    0            ...
# 1178277844     10k    00_00_visit    0            ...
# 1622660825     10k    00_00_visit    0            ...
#
#                                                   family_history_number_adopted_brothers  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                 0
# 5027574288     10k    00_00_visit    0                                                 0
# 7783260382     10k    00_00_visit    0                                                 0
# 1178277844     10k    00_00_visit    0                                                 0
# 1622660825     10k    00_00_visit    0                                                 0
#
#                                                   family_history_number_full_sisters  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                             0
# 5027574288     10k    00_00_visit    0                                             0
# 7783260382     10k    00_00_visit    0                                             1
# 1178277844     10k    00_00_visit    0                                             0
# 1622660825     10k    00_00_visit    0                                             0
#
#                                                   family_history_number_adopted_sisters  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                0
# 5027574288     10k    00_00_visit    0                                                0
# 7783260382     10k    00_00_visit    0                                                0
# 1178277844     10k    00_00_visit    0                                                0
# 1622660825     10k    00_00_visit    0                                                0
#
#                                                              family_history_past_siblings_illness_1  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            [None of the above (group 2), Do not know (gro...
# 5027574288     10k    00_00_visit    0                                              [Heart disease]
# 7783260382     10k    00_00_visit    0                                [None of the above (group 2)]
# 1178277844     10k    00_00_visit    0            [None of the above (group 2), Do not know (gro...
# 1622660825     10k    00_00_visit    0            [None of the above (group 2), Do not know (gro...
#
#                                                  family_history_past_adopted_siblings_illness_1  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                       []
# 5027574288     10k    00_00_visit    0                                                       []
# 7783260382     10k    00_00_visit    0                                                       []
# 1178277844     10k    00_00_visit    0                                                       []
# 1622660825     10k    00_00_visit    0                                                       []
#
#                                                  family_history_past_siblings_illness_2  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                    [None of the above (group 2)]
# 5027574288     10k    00_00_visit    0                                               []
# 7783260382     10k    00_00_visit    0                    [None of the above (group 2)]
# 1178277844     10k    00_00_visit    0                    [None of the above (group 2)]
# 1622660825     10k    00_00_visit    0                    [None of the above (group 2)]
#
#                                                  family_history_past_adopted_siblings_illness_2  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                       []
# 5027574288     10k    00_00_visit    0                                                       []
# 7783260382     10k    00_00_visit    0                                                       []
# 1178277844     10k    00_00_visit    0                                                       []
# 1622660825     10k    00_00_visit    0                                                       []
#
#                                                  family_history_number_older_siblings  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                              0
# 5027574288     10k    00_00_visit    0                                              0
# 7783260382     10k    00_00_visit    0                                              0
# 1178277844     10k    00_00_visit    0                                              0
# 1622660825     10k    00_00_visit    0                                              0
#
#                                                  family_history_non_accidental_death  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                            No
# 5027574288     10k    00_00_visit    0                                           NaN
# 7783260382     10k    00_00_visit    0                                            No
# 1178277844     10k    00_00_visit    0                                            No
# 1622660825     10k    00_00_visit    0                                            No
#
#                                                             data_source
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            follow_up_ukbb_survey
# 5027574288     10k    00_00_visit    0                             <NA>
# 7783260382     10k    00_00_visit    0              initial_ukbb_survey
# 1178277844     10k    00_00_visit    0            follow_up_ukbb_survey
# 1622660825     10k    00_00_visit    0              initial_ukbb_survey
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Data coding
# Data codings are used to encode actual answers for categorical features in english and hebrew.

# %%
df_codes = pl.data_codings
df_codes.head()
# Out:
#   code_number  coding                                            english  \
# 0      001_03       0                                     asia/jerusalem
# 1      062_02       1                                             BRCA-1
# 2      062_02       2                                             BRCA-2
# 3      062_02      -1                                        Do not know
# 4      062_03       1  A relative of mine got breast, ovarian, or pro...
#
#                                               hebrew  answer_field_name  \
# 0                                          זמן ישראל                NaN
# 1                                             BRCA-1        brca_type_1
# 2                                             BRCA-2        brca_type_2
# 3                                          לא יודע/ת        brca_type_3
# 4  קרוב/ת משפחה חלה/תה בסרטן השד, השחלה, או הערמו...  brca_indication_1
#
#         sexed ukbb_compatible  ukbb_similar_coding scripting_instruction  \
# 0         NaN           False                  NaN                   NaN
# 1  Both sexes             NaN                  NaN                   NaN
# 2  Both sexes             NaN                  NaN                   NaN
# 3  Both sexes             NaN                  NaN                  NMUL
# 4  Both sexes             NaN                  NaN                   NaN
#
#   description notes
# 0    Timezone   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN

# %% [markdown]
# Each column represents a single question. Answers are saved as numbers.
# The type of the question (integer, or category with single/multiple choice) can be found in the data dictionary.

# %%
pl.dict['field_type'].value_counts()
# Out:
# field_type
# Integer                   27
# Categorical (single)      15
# Categorical (multiple)    14
# Datetime                   2
# Date                       2
# Name: count, dtype: int64

# %% [markdown]
# ### Numeric questions

# %% [markdown]
# For numeric questions the answers are the numbers entered when filling the survey.

# %%
pl.dict[pl.dict['field_type'] == 'Integer'].head()
# Out:
#                                folder_id      feature_set  \
# tabular_field_name
# hypertension_family_number            52  initial_medical
# hyperlipidemia_family_number          52  initial_medical
# type_1_diabetes_family_number         52  initial_medical
# type_2_diabetes_family_number         52  initial_medical
# stroke_family_number                  52  initial_medical
#
#                                                 field_string  \
# tabular_field_name
# hypertension_family_number        Hypertension family number
# hyperlipidemia_family_number    Hyperlipidemia family number
# type_1_diabetes_family_number  Type 1 diabetes family number
# type_2_diabetes_family_number  Type 2 diabetes family number
# stroke_family_number                    Stroke family number
#
#                                                     relative_location  \
# tabular_field_name
# hypertension_family_number     family_history/initial_medical.parquet
# hyperlipidemia_family_number   family_history/initial_medical.parquet
# type_1_diabetes_family_number  family_history/initial_medical.parquet
# type_2_diabetes_family_number  family_history/initial_medical.parquet
# stroke_family_number           family_history/initial_medical.parquet
#
#                                bulk_file_extension  bulk_dictionary  \
# tabular_field_name
# hypertension_family_number                     NaN              NaN
# hyperlipidemia_family_number                   NaN              NaN
# type_1_diabetes_family_number                  NaN              NaN
# type_2_diabetes_family_number                  NaN              NaN
# stroke_family_number                           NaN              NaN
#
#                                                               description_string  \
# tabular_field_name
# hypertension_family_number     How many of your close family members have hig...
# hyperlipidemia_family_number   How many of your close family members have ele...
# type_1_diabetes_family_number  How many of your close family members have typ...
# type_2_diabetes_family_number  How many of your close family members have typ...
# stroke_family_number           How many of your close family members have had...
#
#                               field_type   array pandas_dtype stability units  \
# tabular_field_name
# hypertension_family_number       Integer  Single          int  Accruing   NaN
# hyperlipidemia_family_number     Integer  Single          int  Accruing   NaN
# type_1_diabetes_family_number    Integer  Single          int  Accruing   NaN
# type_2_diabetes_family_number    Integer  Single          int  Accruing   NaN
# stroke_family_number             Integer  Single          int  Accruing   NaN
#
#                                sampling_rate   strata       sexed      debut  \
# tabular_field_name
# hypertension_family_number               NaN  Primary  Both sexes  2/26/2020
# hyperlipidemia_family_number             NaN  Primary  Both sexes  2/26/2020
# type_1_diabetes_family_number            NaN  Primary  Both sexes  2/26/2020
# type_2_diabetes_family_number            NaN  Primary  Both sexes  2/26/2020
# stroke_family_number                     NaN  Primary  Both sexes  2/26/2020
#
#                                completed data_coding
# tabular_field_name
# hypertension_family_number           NaN         NaN
# hyperlipidemia_family_number         NaN         NaN
# type_1_diabetes_family_number        NaN         NaN
# type_2_diabetes_family_number        NaN         NaN
# stroke_family_number                 NaN         NaN

# %%
# filter out baseline visit
col = 'hypertension_family_number'

df = pl[[col, 'age', 'sex', 'collection_date']].loc[:,:,"00_00_visit",:,:]

df.head()
# Out:
# /home/ec2-user/miniconda3/lib/python3.11/site-packages/pheno_utils/pheno_loader.py:460: UserWarning: Fields not found: ['collection_date']
#   warnings.warn(f'Fields not found: {not_found}')
#                                    hypertension_family_number        age  \
# participant_id cohort array_index
# 5516424321     10k    0                                     0  54.447672
# 5027574288     10k    0                                     0  54.169913
# 7783260382     10k    0                                     0  45.892093
# 1178277844     10k    0                                     0  44.435100
# 1622660825     10k    0                                     0  44.621536
#
#                                       sex
# participant_id cohort array_index
# 5516424321     10k    0            Female
# 5027574288     10k    0              Male
# 7783260382     10k    0              Male
# 1178277844     10k    0            Female
# 1622660825     10k    0              Male

# %% [markdown]
# ### Categorical single choice questions

# %% [markdown]
# For categorical qustions, answers are coded according to the data coding. The automatic setting for PhenoLoader shows the values in english.

# %%
single_question = 'early_life_adopted'
pl[single_question][single_question].value_counts()
# Out:
# early_life_adopted
# No             314
# Yes              2
# Do not know      1
# Name: count, dtype: int64

# %% [markdown]
# To view the data codings you can set the preferred_language to 'coding' in PhenoLoader function.

# %%
pl = PhenoLoader('family_history', preferred_language='coding', base_path='s3://pheno-synthetic-data/data')

# %%
print(single_question, 'mapping:', pl.dict.loc[single_question]['data_coding'])
pl[single_question][single_question].value_counts()
# Out:
# early_life_adopted mapping: 100349
# early_life_adopted
# No             314
# Yes              2
# Do not know      1
# Name: count, dtype: int64

# %% [markdown]
# To change the representation of the answers, we can use the function tranform_answers from pheno_utils.questionnaires_handler or adjust the parameter of preferred_language in the PhenoLoader function (defaul is set to english).

# %%
from pheno_utils.questionnaires_handler import transform_answers

# %% [markdown]
# Transform to Hebrew

# %%
tranformed_hebrew = transform_answers(single_question, pl[single_question][single_question], transform_from='Coding', transform_to='Hebrew', dict_df=pl.dict, mapping_df=df_codes)
print(single_question, pl.dict.loc[single_question]['data_coding'])
tranformed_hebrew.value_counts()
# Out:
# early_life_adopted 100349
# early_life_adopted
# No             314
# Yes              2
# Do not know      1
# Name: count, dtype: int64

# %% [markdown]
# Transorm to English

# %%
tranformed_english = transform_answers(single_question, pl[single_question][single_question], transform_from='Coding', transform_to='English', dict_df=pl.dict, mapping_df=df_codes)
print(single_question, pl.dict.loc[single_question]['data_coding'])
tranformed_english.value_counts()
# Out:
# early_life_adopted 100349
# early_life_adopted
# No             314
# Yes              2
# Do not know      1
# Name: count, dtype: int64

# %% [markdown]
# ### Categorical multiple questions

# %% [markdown]
# Catrgorical multiple choice questions are coded in the same way as categorical single questions, but multiple answers are saved in a list in each row.

# %%
multiple = pl.dict[pl.dict['field_type'] == 'Categorical (multiple)'].index.values.tolist()
# Select a random numeric question
multiple_question = random.choice(multiple)


if isinstance(pl.dict.loc[multiple_question]['data_coding'], pd.Series):
    code = pl.dict.loc[multiple_question]['data_coding'][0]
else:
    code = pl.dict.loc[multiple_question]['data_coding']
    
print(multiple_question, code)
pl[multiple_question][multiple_question].value_counts()

tranformed_english = transform_answers(multiple_question, pl[multiple_question][multiple_question], transform_from='coding', transform_to='english', 
                                     dict_df=pl.dict, mapping_df=df_codes)
# Out:
# family_history_past_father_illness_2 1010

# %%
from collections import Counter
# Flatten the list of lists into a single list
flattened = [item for sublist in tranformed_english.dropna() for item in sublist]

# Count the frequency of each answer
answer_counts = Counter(flattened)

# Display the counts
print(answer_counts)
# Out:
# Counter({'None of the above (group 2)': 295, 'Do not know (group 2)': 74, 'Severe depression': 59, 'Prostate cancer': 34, 'Bowel cancer': 25, 'Prefer not to answer (group 2)': 13, "Parkinson's disease": 11, 'Lung cancer': 1})
