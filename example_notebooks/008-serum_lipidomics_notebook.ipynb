# %% [markdown]
# # Serum lipidomics dataset
#
# ### Description
#
# High throughput untargeted lipidomics in serum by Ultra-High-Performance Liquid Chromatography Electrospray ionization High-resolution mass spectrometry (UHPLC-ESI-HRMS).
#
# ### Introduction
#
# The serum metabolome is known to represent a variety of environmental, genetic and other endogenous factors (Bar et al. 2020). Lipidomics is a subfield of metabolomics, which is defined as the study of pathways and networks of cellular lipids in biological systems. Lipids perform various functions within the body, from structural components of cell membranes, to energy reserve and regulating hormones. These pivotal functions highlight circulating lipids as playing a key role in a number of age-related diseases such as cardiovascular disease and stroke (Holmes et al. 2018; Michos et al. 2019).
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# The data acquisition process can be broken down into these three main stages:
# 1. Sample preparation and experimental design, performed by the wet lab at Weizmann
# 2. Operating the MS machines to obtain the raw spectral data, performed by the Weizmann service unit
# 3. Processing the raw spectral data to obtain the final format for research, performed by the computational lab at Weizmann
#
# #### Sample preparation and experimental design
#
# The process starts with drawing blood from the participants during their visit to the assessment center (see Sample inventory for details). Serum is extracted from the sample and is aliquoted into 5 smaller tubes. All the barcodes mapping are currently documented in the LabCollector.
# The team at the wet lab performs the sample preparation and samples are arranged in working plates of size 96.
# Every plate contains 92 samples from study participants, and 4 QC samples that will be used for systematic bias correction. The QC includes two types:
# 1. Empty well for blank (position 93 in the plate)
# 2. Anchor sample - this is a sample that was pooled from a large number of study participants, and is used as validation for the statistical correction methods. Same sample is used repeatedly. (position 94 in the plate)
# 3. Two NIST samples - these are standardized technical replicates that contain a predefined mixture of human serum metabolites. These samples are later used for running order and batch correction of the data. (positions 95-96 in the plate)
#
# For every plate, the team at the wet lab produces an experimental design file that describes the layout for the analysis of the plate. Mainly, it describes the ordering of the samples to be injected into the MS machine, including the various sample types (10K, empty, NIST, anchor), the tube barcode, their quantity and location. Systematic removal of technical noise is partly performed based on this experimental design file.
#
# #### Operating the MS machines to obtain the raw spectral data
#
# The service unit in Weizmann is responsible to operate the MS machines in order to profile the samples. According to the service unit staff, initial QC checks are performed after the injection of every plate, making sure that internal standards are identifiable, and that the sensitivity of the MS machine is within reasonable limits.
#
# #### Processing the raw spectral data to obtain the final format for research
#
# Lipid annotations were obtained by comparing the mz, retention times and ccs values to equivalent empirical measurements from a library that was profiled on the same instruments with longer running times (26 minutes).
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `serum_lipidomics.parquet`
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/008-serum_lipidomics.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/8)

# %%
# %load_ext autoreload
# %autoreload 2

from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('serum_lipidomics', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for serum_lipidomics with
# 192 fields
# 2 tables: ['serum_lipidomics', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                         folder_id       feature_set  \
# tabular_field_name
# collection_date                 8  serum_lipidomics
# collection_timestamp            8  serum_lipidomics
# timezone                        8  serum_lipidomics
# 22:6_cholesteryl_ester          8  serum_lipidomics
# acca_c10:0                      8  serum_lipidomics
# ...                           ...               ...
# lysopc_22:6                     8  serum_lipidomics
# lysope_16:0                     8  serum_lipidomics
# lysope_18:0                     8  serum_lipidomics
# lysope_18:1                     8  serum_lipidomics
# lysope_18:2                     8  serum_lipidomics
#
#                                         field_string  bulk_dictionary  \
# tabular_field_name
# collection_date         Collection date (YYYY-MM-DD)              NaN
# collection_timestamp            Collection timestamp              NaN
# timezone                                    Timezone              NaN
# 22:6_cholesteryl_ester        22:6 Cholesteryl Ester              NaN
# acca_c10:0                                AcCa C10:0              NaN
# ...                                              ...              ...
# lysopc_22:6                              lysoPC 22:6              NaN
# lysope_16:0                              lysoPE 16:0              NaN
# lysope_18:0                              lysoPE 18:0              NaN
# lysope_18:1                              lysoPE 18:1              NaN
# lysope_18:2                              lysoPE 18:2              NaN
#
#                         data_coding  completed            field_type  \
# tabular_field_name
# collection_date                 NaN        NaN                  Date
# collection_timestamp            NaN        NaN              Datetime
# timezone                        NaN        NaN  Categorical (single)
# 22:6_cholesteryl_ester          NaN        NaN            Continuous
# acca_c10:0                      NaN        NaN            Continuous
# ...                             ...        ...                   ...
# lysopc_22:6                     NaN        NaN            Continuous
# lysope_16:0                     NaN        NaN            Continuous
# lysope_18:0                     NaN        NaN            Continuous
# lysope_18:1                     NaN        NaN            Continuous
# lysope_18:2                     NaN        NaN            Continuous
#
#                         bulk_file_extension  \
# tabular_field_name
# collection_date                         NaN
# collection_timestamp                    NaN
# timezone                                NaN
# 22:6_cholesteryl_ester                  NaN
# acca_c10:0                              NaN
# ...                                     ...
# lysopc_22:6                             NaN
# lysope_16:0                             NaN
# lysope_18:0                             NaN
# lysope_18:1                             NaN
# lysope_18:2                             NaN
#
#                                                 relative_location  \
# tabular_field_name
# collection_date         serum_lipidomics/serum_lipidomics.parquet
# collection_timestamp    serum_lipidomics/serum_lipidomics.parquet
# timezone                serum_lipidomics/serum_lipidomics.parquet
# 22:6_cholesteryl_ester  serum_lipidomics/serum_lipidomics.parquet
# acca_c10:0              serum_lipidomics/serum_lipidomics.parquet
# ...                                                           ...
# lysopc_22:6             serum_lipidomics/serum_lipidomics.parquet
# lysope_16:0             serum_lipidomics/serum_lipidomics.parquet
# lysope_18:0             serum_lipidomics/serum_lipidomics.parquet
# lysope_18:1             serum_lipidomics/serum_lipidomics.parquet
# lysope_18:2             serum_lipidomics/serum_lipidomics.parquet
#
#                         description_string  sampling_rate stability  \
# tabular_field_name
# collection_date                        NaN            NaN       NaN
# collection_timestamp                   NaN            NaN       NaN
# timezone                               NaN            NaN       NaN
# 22:6_cholesteryl_ester                 NaN            NaN  Accruing
# acca_c10:0                             NaN            NaN  Accruing
# ...                                    ...            ...       ...
# lysopc_22:6                            NaN            NaN  Accruing
# lysope_16:0                            NaN            NaN  Accruing
# lysope_18:0                            NaN            NaN  Accruing
# lysope_18:1                            NaN            NaN  Accruing
# lysope_18:2                            NaN            NaN  Accruing
#
#                                     units   strata       sexed   array  \
# tabular_field_name
# collection_date                       NaN      NaN         NaN  Single
# collection_timestamp                  NaN      NaN         NaN  Single
# timezone                              NaN      NaN         NaN  Single
# 22:6_cholesteryl_ester  Intensity (log10)  Primary  Both sexes  Single
# acca_c10:0              Intensity (log10)  Primary  Both sexes  Single
# ...                                   ...      ...         ...     ...
# lysopc_22:6             Intensity (log10)  Primary  Both sexes  Single
# lysope_16:0             Intensity (log10)  Primary  Both sexes  Single
# lysope_18:0             Intensity (log10)  Primary  Both sexes  Single
# lysope_18:1             Intensity (log10)  Primary  Both sexes  Single
# lysope_18:2             Intensity (log10)  Primary  Both sexes  Single
#
#                         list_of_tags       debut transformation  \
# tabular_field_name
# collection_date                  NaN         NaN            NaN
# collection_timestamp             NaN         NaN            NaN
# timezone                         NaN         NaN            NaN
# 22:6_cholesteryl_ester           NaN  2019-02-19          log1p
# acca_c10:0                       NaN  2019-02-19          log1p
# ...                              ...         ...            ...
# lysopc_22:6                      NaN  2019-02-19          log1p
# lysope_16:0                      NaN  2019-02-19          log1p
# lysope_18:0                      NaN  2019-02-19          log1p
# lysope_18:1                      NaN  2019-02-19          log1p
# lysope_18:2                      NaN  2019-02-19          log1p
#
#                                           pandas_dtype
# tabular_field_name
# collection_date                         datetime64[ns]
# collection_timestamp    datetime64[ns, Asia/Jerusalem]
# timezone                                        string
# 22:6_cholesteryl_ester                           float
# acca_c10:0                                       float
# ...                                                ...
# lysopc_22:6                                      float
# lysope_16:0                                      float
# lysope_18:0                                      float
# lysope_18:1                                      float
# lysope_18:2                                      float
#
# [200 rows x 20 columns]

# %%
pl[pl.fields]
# Out:
#                                                   22:6_cholesteryl_ester  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                          1.506640
# 5027574288     10k    00_00_visit    0                          0.086996
# 7783260382     10k    00_00_visit    0                          0.799311
# 1178277844     10k    00_00_visit    0                          1.054378
# 1622660825     10k    00_00_visit    0                          1.512437
# ...                                                                  ...
# 9642255339     10k    02_01_visit    0                          0.044900
# 9668685572     10k    02_01_visit    0                          0.481544
# 9704705313     10k    02_01_visit    0                          0.720824
# 9887688063     10k    01_01_visit    0                          1.512437
# 9992994539     10k    02_00_visit    0                               NaN
#
#                                                   acca_c10:0  acca_c16:0  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0              0.067331    0.574804
# 5027574288     10k    00_00_visit    0              0.039267    0.436243
# 7783260382     10k    00_00_visit    0              0.091033    0.287120
# 1178277844     10k    00_00_visit    0              0.450465    0.412886
# 1622660825     10k    00_00_visit    0                   NaN    0.317224
# ...                                                      ...         ...
# 9642255339     10k    02_01_visit    0              0.324396    0.440473
# 9668685572     10k    02_01_visit    0              0.094496         NaN
# 9704705313     10k    02_01_visit    0              0.565827         NaN
# 9887688063     10k    01_01_visit    0              0.372927    0.362831
# 9992994539     10k    02_00_visit    0              0.292124    0.416496
#
#                                                   acca_c18:1  cer_d18:0/c16:0  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0              0.288994              NaN
# 5027574288     10k    00_00_visit    0                   NaN              NaN
# 7783260382     10k    00_00_visit    0              0.524679              NaN
# 1178277844     10k    00_00_visit    0              0.299197              NaN
# 1622660825     10k    00_00_visit    0              0.201176              NaN
# ...                                                      ...              ...
# 9642255339     10k    02_01_visit    0              0.302310         0.442694
# 9668685572     10k    02_01_visit    0              0.183324              NaN
# 9704705313     10k    02_01_visit    0              0.322308              NaN
# 9887688063     10k    01_01_visit    0              0.227483         0.878693
# 9992994539     10k    02_00_visit    0              0.631966              NaN
#
#                                                   cer_d18:1/c12:0  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                   0.395644
# 5027574288     10k    00_00_visit    0                        NaN
# 7783260382     10k    00_00_visit    0                   0.366619
# 1178277844     10k    00_00_visit    0                   0.388378
# 1622660825     10k    00_00_visit    0                        NaN
# ...                                                           ...
# 9642255339     10k    02_01_visit    0                   0.279615
# 9668685572     10k    02_01_visit    0                   0.371967
# 9704705313     10k    02_01_visit    0                   0.382906
# 9887688063     10k    01_01_visit    0                        NaN
# 9992994539     10k    02_00_visit    0                   0.286736
#
#                                                   cer_d18:1/c14:0  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0
\
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            0.454695   1.309643
# 5027574288     10k    00_00_visit    0            0.111546   2.090190
# 7783260382     10k    00_00_visit    0            0.238115   1.386415
# 1178277844     10k    00_00_visit    0            0.633567   1.244331
# 1622660825     10k    00_00_visit    0                 NaN   0.000000
# ...                                                    ...        ...
# 9642255339     10k    02_01_visit    0            0.898002   2.889878
# 9668685572     10k    02_01_visit    0            0.088256   2.420624
# 9704705313     10k    02_01_visit    0                 NaN   1.596027
# 9887688063     10k    01_01_visit    0            0.112787   0.731110
# 9992994539     10k    02_00_visit    0                 NaN   1.198461
#
#                                                   tag_62:14        timezone  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0             1.605583  asia/jerusalem
# 5027574288     10k    00_00_visit    0             0.246051  asia/jerusalem
# 7783260382     10k    00_00_visit    0             1.067413  asia/jerusalem
# 1178277844     10k    00_00_visit    0             0.604299  asia/jerusalem
# 1622660825     10k    00_00_visit    0             0.274546  asia/jerusalem
# ...                                                     ...             ...
# 9642255339     10k    02_01_visit    0             1.605583  asia/jerusalem
# 9668685572     10k    02_01_visit    0             0.372946  asia/jerusalem
# 9704705313     10k    02_01_visit    0             0.614243  asia/jerusalem
# 9887688063     10k    01_01_visit    0             0.385323  asia/jerusalem
# 9992994539     10k    02_00_visit    0             0.363428  asia/jerusalem
#
#                                                         age     sex
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            54.447672  Female
# 5027574288     10k    00_00_visit    0            54.169913    Male
# 7783260382     10k    00_00_visit    0            45.892093    Male
# 1178277844     10k    00_00_visit    0            44.435100  Female
# 1622660825     10k    00_00_visit    0            44.621536    Male
# ...                                                     ...     ...
# 9642255339     10k    02_01_visit    0            61.462461    Male
# 9668685572     10k    02_01_visit    0            55.199891  Female
# 9704705313     10k    02_01_visit    0            42.207211    Male
# 9887688063     10k    01_01_visit    0            57.157314    Male
# 9992994539     10k    02_00_visit    0            51.376179    Male
#
# [603 rows x 192 columns]

# %% [markdown]
# # Plot histogram

# %%
from pheno_utils.basic_plots import hist_ecdf_plots

# %%
# filter out baseline visit
col = "22:6_cholesteryl_ester"

df = pl[[col, "age", "sex", "collection_date"]].loc[:,:,"00_00_visit",:,:]

df.head()
# Out:
#                                    22:6_cholesteryl_ester        age     sex  \
# participant_id cohort array_index
# 5516424321     10k    0                          1.506640  54.447672  Female
# 5027574288     10k    0                          0.086996  54.169913    Male
# 7783260382     10k    0                          0.799311  45.892093    Male
# 1178277844     10k    0                          1.054378  44.435100  Female
# 1622660825     10k    0                          1.512437  44.621536    Male
#
#                                   collection_date
# participant_id cohort array_index
# 5516424321     10k    0                2020-07-12
# 5027574288     10k    0                2020-07-09
# 7783260382     10k    0                2020-07-06
# 1178277844     10k    0                2020-07-09
# 1622660825     10k    0                2020-07-12

# %%
# plot histogram and ecdf
hist_ecdf_plots(df.dropna(subset=[col,"sex", "age"]), col, gender_col="sex")

# stats
display(df[col].describe().to_frame().T)
# Out:
#                         count      mean       std     min       25%       50%  \
# 22:6_cholesteryl_ester  463.0  1.081148  0.458901  0.0449  0.761431  1.208086
#
#                              75%       max
# 22:6_cholesteryl_ester  1.512437  1.512437

# %% [markdown]
# # Plot age-sex reference plots

# %%
# from pheno_utils.age_reference_plots import GenderAgeRefPlot

# %%
# gender_refplots = GenderAgeRefPlot(df.dropna(subset=[col,"sex", "age"]), "22:6_cholesteryl_ester", age_col="age")
# gender_refplots.plot()
