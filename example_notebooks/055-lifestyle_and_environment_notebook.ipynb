# %% [markdown]
# # Lifestyle and environment
#
# ### Description
#
# Lifestyle and environmental factors encompass a wide range of influences on an individual's health and well-being. These factors may include behaviors such as diet, physical activity, sleep patterns, smoking, and alcohol consumption, as well as environmental exposures like air quality, pollution, and climate. Together, they play a crucial role in determining overall health outcomes, impacting both the prevention and progression of diseases.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes lifestyle and enviroment data, captured through two lifestyle surveys.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `'lifestyle_and_environment.parquet'.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/055-lifestyle_and_environment.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/55)

# %%
# %load_ext autoreload
# %autoreload 2
from pheno_utils import PhenoLoader
import pandas as pd
import random

# %%
pl = PhenoLoader('lifestyle_and_environment', base_path='s3://pheno-synthetic-data/data')
pl
# Out:
# PhenoLoader for lifestyle_and_environment with
# 161 fields
# 2 tables: ['lifestyle_and_environment', 'age_sex']

# %% [markdown]
# ## Data dictionary

# %%
pl.dict.head()
# Out:
#                                     folder_id                feature_set  \
# tabular_field_name
# collection_timestamp                       55  lifestyle_and_environment
# collection_date                            55  lifestyle_and_environment
# timezone                                   55  lifestyle_and_environment
# data_source                                55  lifestyle_and_environment
# activity_walking_10min_days_weekly         55  lifestyle_and_environment
#
#                                                               field_string  \
# tabular_field_name
# collection_timestamp                                       Collection time
# collection_date                                            Collection date
# timezone                                                          Timezone
# data_source                                                    Data source
# activity_walking_10min_days_weekly  Number of days/week walked 10+ minutes
#
#                                                                     relative_location  \
# tabular_field_name
# collection_timestamp                lifestyle_and_environment/lifestyle_and_enviro...
# collection_date                     lifestyle_and_environment/lifestyle_and_enviro...
# timezone                            lifestyle_and_environment/lifestyle_and_enviro...
# data_source                         lifestyle_and_environment/lifestyle_and_enviro...
# activity_walking_10min_days_weekly  lifestyle_and_environment/lifestyle_and_enviro...
#
#                                     bulk_file_extension  bulk_dictionary  \
# tabular_field_name
# collection_timestamp                                NaN              NaN
# collection_date                                     NaN              NaN
# timezone                                            NaN              NaN
# data_source                                         NaN              NaN
# activity_walking_10min_days_weekly                  NaN              NaN
#
#                                                                    description_string  \
# tabular_field_name
# collection_timestamp                                                  Collection time
# collection_date                                                       Collection date
# timezone                                                                     Timezone
# data_source                                        Data source of survey information
# activity_walking_10min_days_weekly  In a typical WEEK, on how many days did you wa...
#
#                                               field_type   array  \
# tabular_field_name
# collection_timestamp                            Datetime  Single
# collection_date                                     Date  Single
# timezone                            Categorical (single)  Single
# data_source                                         Text  Single
# activity_walking_10min_days_weekly               Integer  Single
#
#                                                       pandas_dtype stability  \
# tabular_field_name
# collection_timestamp                datetime64[ns, Asia/Jerusalem]  Accruing
# collection_date                                     datetime64[ns]  Accruing
# timezone                                                  category  Accruing
# data_source                                                 string  Accruing
# activity_walking_10min_days_weekly                             int  Accruing
#
#                                         units  sampling_rate           strata  \
# tabular_field_name
# collection_timestamp                      NaN            NaN  Collection time
# collection_date                           NaN            NaN  Collection time
# timezone                                  NaN            NaN  Collection time
# data_source                               NaN            NaN        Auxiliary
# activity_walking_10min_days_weekly  Days/Week            NaN          Primary
#
#                                          sexed     debut  completed  \
# tabular_field_name
# collection_timestamp                Both sexes  1/9/2019        NaN
# collection_date                     Both sexes  1/9/2019        NaN
# timezone                            Both sexes  1/9/2019        NaN
# data_source                         Both sexes  1/9/2019        NaN
# activity_walking_10min_days_weekly  Both sexes  1/9/2019        NaN
#
#                                    data_coding
# tabular_field_name
# collection_timestamp                       NaN
# collection_date                            NaN
# timezone                                   NaN
# data_source                                NaN
# activity_walking_10min_days_weekly         NaN

# %% [markdown]
# ## Dataset

# %%
pl.dfs['lifestyle_and_environment'].head()
# Out:
#                                                           collection_timestamp  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0           2022-08-02 09:32:01.373358080
# 5027574288     10k    00_00_visit    0           2023-01-23 04:30:06.857399296
# 7783260382     10k    00_00_visit    0           2021-06-12 20:58:43.712332800
# 1178277844     10k    00_00_visit    0           2022-12-14 07:48:11.993735936
# 1622660825     10k    00_00_visit    0           2021-06-17 19:35:15.170488064
#
#                                                                collection_date  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0           2022-10-27 17:21:28.801640960
# 5027574288     10k    00_00_visit    0           2023-05-09 07:50:09.348581376
# 7783260382     10k    00_00_visit    0           2020-04-18 19:37:33.439312640
# 1178277844     10k    00_00_visit    0           2023-05-17 00:00:00.000000000
# 1622660825     10k    00_00_visit    0           2021-12-27 13:58:43.397170688
#
#                                                         timezone  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            asia/jerusalem
# 5027574288     10k    00_00_visit    0            asia/jerusalem
# 7783260382     10k    00_00_visit    0            asia/jerusalem
# 1178277844     10k    00_00_visit    0            asia/jerusalem
# 1622660825     10k    00_00_visit    0            asia/jerusalem
#
#                                                             data_source  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0            follow_up_ukbb_survey
# 5027574288     10k    00_00_visit    0            follow_up_ukbb_survey
# 7783260382     10k    00_00_visit    0              initial_ukbb_survey
# 1178277844     10k    00_00_visit    0              initial_ukbb_survey
# 1622660825     10k    00_00_visit    0            follow_up_ukbb_survey
#
#                                                   activity_walking_10min_days_weekly  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                             5
# 5027574288     10k    00_00_visit    0                                             7
# 7783260382     10k    00_00_visit    0                                             5
# 1178277844     10k    00_00_visit    0                                             5
# 1622660825     10k    00_00_visit    0                                             1
#
#                                                   activity_walking_minutes_daily  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                        22
# 5027574288     10k    00_00_visit    0                                        10
# 7783260382     10k    00_00_visit    0                                         0
# 1178277844     10k    00_00_visit    0                                         0
# 1622660825     10k    00_00_visit    0                                         6
#
#                                                   activity_moderate_days_weekly  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                        2
# 5027574288     10k    00_00_visit    0                                        1
# 7783260382     10k    00_00_visit    0                                        0
# 1178277844     10k    00_00_visit    0                                        0
# 1622660825     10k    00_00_visit    0                                        0
#
#                                                   activity_moderate_minutes_daily  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                         25
# 5027574288     10k    00_00_visit    0                                         21
# 7783260382     10k    00_00_visit    0                                         21
# 1178277844     10k    00_00_visit    0                                          0
# 1622660825     10k    00_00_visit    0                                         78
#
#                                                   activity_vigorous_days_weekly  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                        0
# 5027574288     10k    00_00_visit    0                                        0
# 7783260382     10k    00_00_visit    0                                        0
# 1178277844     10k    00_00_visit    0                                        0
# 1622660825     10k    00_00_visit    0                                        0
#
#                                                   activity_vigorous_minutes_daily  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                         32
# 5027574288     10k    00_00_visit    0                                          6
# 7783260382     10k    00_00_visit    0                                          0
# 1178277844     10k    00_00_visit    0                                          0
# 1622660825     10k    00_00_visit    0                                          3
#
#                                                   ...  \
# participant_id cohort research_stage array_index  ...
# 5516424321     10k    00_00_visit    0            ...
# 5027574288     10k    00_00_visit    0            ...
# 7783260382     10k    00_00_visit    0            ...
# 1178277844     10k    00_00_visit    0            ...
# 1622660825     10k    00_00_visit    0            ...
#
#                                                                           extra_diet_press_oil_type  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                                           []
# 5027574288     10k    00_00_visit    0                                                [Refined oil]
# 7783260382     10k    00_00_visit    0            [Cold pressed olive oil, Refined oil, Oil - un...
# 1178277844     10k    00_00_visit    0            [Cold pressed olive oil, Refined oil, Oil - un...
# 1622660825     10k    00_00_visit    0                                                [Refined oil]
#
#                                                  extra_diet_main_dairy_source  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                    NaN
# 5027574288     10k    00_00_visit    0                                    NaN
# 7783260382     10k    00_00_visit    0                                   Beef
# 1178277844     10k    00_00_visit    0                                   Beef
# 1622660825     10k    00_00_visit    0                                    NaN
#
#                                                  extra_diet_cheese_fat_percentage  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                        NaN
# 5027574288     10k    00_00_visit    0                                        NaN
# 7783260382     10k    00_00_visit    0                      9% fat or less cheese
# 1178277844     10k    00_00_visit    0                                 Fat cheese
# 1622660825     10k    00_00_visit    0                                        NaN
#
#                                                  extra_diet_moldy_cheese_frequency  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                         NaN
# 5027574288     10k    00_00_visit    0                                         NaN
# 7783260382     10k    00_00_visit    0                       Once every few months
# 1178277844     10k    00_00_visit    0                       Once every few months
# 1622660825     10k    00_00_visit    0                                         NaN
#
#                                                  extra_diet_cereal_sugared  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                 NaN
# 5027574288     10k    00_00_visit    0                                 NaN
# 7783260382     10k    00_00_visit    0                          Do not eat
# 1178277844     10k    00_00_visit    0                          Do not eat
# 1622660825     10k    00_00_visit    0                                 NaN
#
#                                                  skin_color  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                  NaN
# 5027574288     10k    00_00_visit    0                  NaN
# 7783260382     10k    00_00_visit    0                 Fair
# 1178277844     10k    00_00_visit    0                 Fair
# 1622660825     10k    00_00_visit    0                  NaN
#
#                                                       skin_ease_of_burn  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                              NaN
# 5027574288     10k    00_00_visit    0                              NaN
# 7783260382     10k    00_00_visit    0            Get moderately tanned
# 1178277844     10k    00_00_visit    0             Never tan, only burn
# 1622660825     10k    00_00_visit    0                              NaN
#
#                                                  skin_past_sunburns  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                            0
# 5027574288     10k    00_00_visit    0                            0
# 7783260382     10k    00_00_visit    0                            2
# 1178277844     10k    00_00_visit    0                            0
# 1622660825     10k    00_00_visit    0                            0
#
#                                                    hair_color  \
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                    NaN
# 5027574288     10k    00_00_visit    0                    NaN
# 7783260382     10k    00_00_visit    0            Light brown
# 1178277844     10k    00_00_visit    0             Dark brown
# 1622660825     10k    00_00_visit    0                    NaN
#
#                                                  activiy_indoors_pc_daily
# participant_id cohort research_stage array_index
# 5516424321     10k    00_00_visit    0                                  0
# 5027574288     10k    00_00_visit    0                                  0
# 7783260382     10k    00_00_visit    0                                  0
# 1178277844     10k    00_00_visit    0                                  0
# 1622660825     10k    00_00_visit    0                                  0
#
# [5 rows x 159 columns]

# %% [markdown]
# ## Data coding
# A data-coding is a mapping between the actual data and the values used to represent it within the database for categorical features.

# %%
df_codes = pl.data_codings
df_codes.head(5)
# Out:
#   code_number  coding                                            english  \
# 0      001_03       0                                     asia/jerusalem
# 1      062_02       1                                             BRCA-1
# 2      062_02       2                                             BRCA-2
# 3      062_02      -1                                        Do not know
# 4      062_03       1  A relative of mine got breast, ovarian, or pro...
#
#                                               hebrew  answer_field_name  \
# 0                                          זמן ישראל                NaN
# 1                                             BRCA-1        brca_type_1
# 2                                             BRCA-2        brca_type_2
# 3                                          לא יודע/ת        brca_type_3
# 4  קרוב/ת משפחה חלה/תה בסרטן השד, השחלה, או הערמו...  brca_indication_1
#
#         sexed ukbb_compatible  ukbb_similar_coding scripting_instruction  \
# 0         NaN           False                  NaN                   NaN
# 1  Both sexes             NaN                  NaN                   NaN
# 2  Both sexes             NaN                  NaN                   NaN
# 3  Both sexes             NaN                  NaN                  NMUL
# 4  Both sexes             NaN                  NaN                   NaN
#
#   description notes
# 0    Timezone   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN

# %% [markdown]
# Each column represents a single question. Answers are saved as numbers.
# The type of the question (integer, or category with single/multiple choice) can be found in the data dictionary.

# %%
pl.dict['field_type'].value_counts()
# Out:
# field_type
# Categorical (single)      100
# Integer                    46
# Categorical (multiple)     10
# Datetime                    1
# Date                        1
# Text                        1
# Name: count, dtype: int64

# %% [markdown]
# ### Numeric questions

# %% [markdown]
# For numeric questions the answers are the numbers entered when filling the survey

# %%
pl.dict[pl.dict['field_type'] == 'Integer'].head()
# Out:
#                                     folder_id                feature_set  \
# tabular_field_name
# activity_walking_10min_days_weekly         55  lifestyle_and_environment
# activity_walking_minutes_daily             55  lifestyle_and_environment
# activity_moderate_days_weekly              55  lifestyle_and_environment
# activity_moderate_minutes_daily            55  lifestyle_and_environment
# activity_vigorous_days_weekly              55  lifestyle_and_environment
#
#                                                                          field_string  \
# tabular_field_name
# activity_walking_10min_days_weekly             Number of days/week walked 10+ minutes
# activity_walking_minutes_daily                                      Duration of walks
# activity_moderate_days_weekly       Number of days/week of moderate physical activ...
# activity_moderate_minutes_daily                         Duration of moderate activity
# activity_vigorous_days_weekly       Number of days/week of vigorous physical activ...
#
#                                                                     relative_location  \
# tabular_field_name
# activity_walking_10min_days_weekly  lifestyle_and_environment/lifestyle_and_enviro...
# activity_walking_minutes_daily      lifestyle_and_environment/lifestyle_and_enviro...
# activity_moderate_days_weekly       lifestyle_and_environment/lifestyle_and_enviro...
# activity_moderate_minutes_daily     lifestyle_and_environment/lifestyle_and_enviro...
# activity_vigorous_days_weekly       lifestyle_and_environment/lifestyle_and_enviro...
#
#                                     bulk_file_extension  bulk_dictionary  \
# tabular_field_name
# activity_walking_10min_days_weekly                  NaN              NaN
# activity_walking_minutes_daily                      NaN              NaN
# activity_moderate_days_weekly                       NaN              NaN
# activity_moderate_minutes_daily                     NaN              NaN
# activity_vigorous_days_weekly                       NaN              NaN
#
#                                                                    description_string  \
# tabular_field_name
# activity_walking_10min_days_weekly  In a typical WEEK, on how many days did you wa...
# activity_walking_minutes_daily      How many minutes did you usually spend walking...
# activity_moderate_days_weekly       In a typical WEEK, on how many days did you do...
# activity_moderate_minutes_daily     How many minutes did you usually spend doing m...
# activity_vigorous_days_weekly       In a typical WEEK, how many days did you do 10...
#
#                                    field_type   array pandas_dtype stability  \
# tabular_field_name
# activity_walking_10min_days_weekly    Integer  Single          int  Accruing
# activity_walking_minutes_daily        Integer  Single          int  Accruing
# activity_moderate_days_weekly         Integer  Single          int  Accruing
# activity_moderate_minutes_daily       Integer  Single          int  Accruing
# activity_vigorous_days_weekly         Integer  Single          int  Accruing
#
#                                           units  sampling_rate   strata  \
# tabular_field_name
# activity_walking_10min_days_weekly    Days/Week            NaN  Primary
# activity_walking_minutes_daily      Minutes/Day            NaN  Primary
# activity_moderate_days_weekly         Days/Week            NaN  Primary
# activity_moderate_minutes_daily     Minutes/Day            NaN  Primary
# activity_vigorous_days_weekly         Days/Week            NaN  Primary
#
#                                          sexed     debut  completed  \
# tabular_field_name
# activity_walking_10min_days_weekly  Both sexes  1/9/2019        NaN
# activity_walking_minutes_daily      Both sexes  1/9/2019        NaN
# activity_moderate_days_weekly       Both sexes  1/9/2019        NaN
# activity_moderate_minutes_daily     Both sexes  1/9/2019        NaN
# activity_vigorous_days_weekly       Both sexes  1/9/2019        NaN
#
#                                    data_coding
# tabular_field_name
# activity_walking_10min_days_weekly         NaN
# activity_walking_minutes_daily             NaN
# activity_moderate_days_weekly              NaN
# activity_moderate_minutes_daily            NaN
# activity_vigorous_days_weekly              NaN

# %%
# filter out baseline visit
col = 'activity_walking_minutes_daily'

df = pl[[col, 'age', 'sex', 'collection_date']].loc[:,:,"00_00_visit",:,:]

df.head()
# Out:
#                                    activity_walking_minutes_daily        age  \
# participant_id cohort array_index
# 5516424321     10k    0                                        22  54.447672
# 5027574288     10k    0                                        10  54.169913
# 7783260382     10k    0                                         0  45.892093
# 1178277844     10k    0                                         0  44.435100
# 1622660825     10k    0                                         6  44.621536
#
#                                       sex               collection_date
# participant_id cohort array_index
# 5516424321     10k    0            Female 2022-10-27 17:21:28.801640960
# 5027574288     10k    0              Male 2023-05-09 07:50:09.348581376
# 7783260382     10k    0              Male 2020-04-18 19:37:33.439312640
# 1178277844     10k    0            Female 2023-05-17 00:00:00.000000000
# 1622660825     10k    0              Male 2021-12-27 13:58:43.397170688

# %%
from pheno_utils.age_reference_plots import GenderAgeRefPlot

gender_refplots = GenderAgeRefPlot(df.dropna(subset=[col,"sex", "age"]), col, age_col="age")
gender_refplots.plot()

# %% [markdown]
# ### Categorical single choice questions

# %% [markdown]
# For categorical qustions, answers are coded according to the data coding. The automatic setting for PhenoLoader shows the values in english.

# %%
single = pl.dict[pl.dict['field_type'] == 'Categorical (single)'].index.values.tolist()
# Select a random numeric question
single_question = random.choice(single)
pl[single_question][single_question].value_counts()
# Out:
# diet_cereal_intake_choice
# Less than one    28
# Do not know       2
# Name: count, dtype: int64

# %% [markdown]
# To view the data codings you can set the preferred_language to 'coding' in PhenoLoader function.

# %%
pl = PhenoLoader('lifestyle_and_environment', preferred_language='coding', base_path='s3://pheno-synthetic-data/data')

# %%
single = pl.dict[pl.dict['field_type'] == 'Categorical (single)'].index.values.tolist()
# Select a random numeric question
single_question = random.choice(single)
pl[single_question][single_question].value_counts()
# Out:
# diet_vegeterian_indicator
# No     295
# Yes     45
# Name: count, dtype: int64

# %% [markdown]
# To change the representation of the answers, we can use the function tranform_answers from pheno_utils.questionnaires_handler.

# %%
from pheno_utils.questionnaires_handler import transform_answers

# %% [markdown]
# Transform to Hebrew

# %%
tranformed_hebrew = transform_answers(single_question, pl[single_question][single_question], transform_from='Coding', transform_to='Hebrew', dict_df=pl.dict, mapping_df=df_codes)
tranformed_hebrew.value_counts()
# Out:
# diet_vegeterian_indicator
# No     295
# Yes     45
# Name: count, dtype: int64

# %% [markdown]
# Transorm to English

# %%
tranformed_english = transform_answers(single_question, pl[single_question][single_question], transform_from='Coding', transform_to='English', dict_df=pl.dict, mapping_df=df_codes)
tranformed_english.value_counts()
# Out:
# diet_vegeterian_indicator
# No     295
# Yes     45
# Name: count, dtype: int64

# %% [markdown]
# ### Categorical multiple choice questions

# %% [markdown]
# Catrgorical multiple choice questions are coded in the same way as categorical single questions, but are saved in a list in each row.

# %%
multiple = pl.dict[pl.dict['field_type'] == 'Categorical (multiple)'].index.values.tolist()
# Select a random numeric question
multiple_question = random.choice(multiple)


if isinstance(pl.dict.loc[multiple_question]['data_coding'], pd.Series):
    code = pl.dict.loc[multiple_question]['data_coding'][0]
else:
    code = pl.dict.loc[multiple_question]['data_coding']
    
print(multiple_question, code)
pl[multiple_question][multiple_question].value_counts()

tranformed_english = transform_answers(multiple_question, pl[multiple_question][multiple_question], transform_from='coding', transform_to='english', 
                                     dict_df=pl.dict, mapping_df=df_codes)
# Out:
# extra_diet_press_oil_type 040_04

# %%
from collections import Counter
# Flatten the list of lists into a single list
flattened = [item for sublist in tranformed_english.dropna() for item in sublist]

# Count the frequency of each answer
answer_counts = Counter(flattened)

# Display the counts
print(answer_counts)
# Out:
# Counter({'Refined oil': 398, 'Oil - unknown type of pickling.': 231, 'Cold pressed olive oil': 225, 'Butter': 213, 'Other cold pressed oil': 42, 'Margarine': 29})
